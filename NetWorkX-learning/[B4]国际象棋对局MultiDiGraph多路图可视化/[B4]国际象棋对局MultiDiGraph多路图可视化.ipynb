# %% [markdown]
# # 导入相关库

# %%
# 图数据挖掘
import networkx as nx

# 数据可视化
import matplotlib.pyplot as plt
# %matplotlib inline

# plt.rcParams['font.sans-serif']=['SimHei']  # 用来正常显示中文标签  
plt.rcParams['axes.unicode_minus']=False  # 用来正常显示负号

# %% [markdown]
# # 数据读取

# %%
import pandas as pd
df = pd.read_csv('chess_masters_WCC.csv')
df
# Out:
#                        Event        Site        Date   EventDate  ECO  Round  \
# 0     World Championship 1st         USA  1886.01.11  1886.01.11  D11      1
# 1     World Championship 1st         USA  1886.01.13  1886.01.11  C47      2
# 2     World Championship 1st         USA  1886.01.15  1886.01.11  D10      3
# 3     World Championship 1st         USA  1886.01.18  1886.01.11  C67      4
# 4     World Championship 1st         USA  1886.01.20  1886.01.11  D10      5
# ..                       ...         ...         ...         ...  ...    ...
# 680  World Championship 31th  Moscow RUS  1985.01.21  1984.09.10  C92     44
# 681  World Championship 31th  Moscow RUS  1985.01.23  1984.09.10  B85     45
# 682  World Championship 31th  Moscow RUS  1985.01.28  1984.09.10  C92     46
# 683  World Championship 31th  Moscow RUS  1985.01.30  1984.09.10  D52     47
# 684  World Championship 31th  Moscow RUS  1985.02.08  1984.09.10  C42     48
#
#                      White                  Black   Result  \
# 0    Zukertort, Johannes H      Steinitz, Wilhelm      0-1
# 1        Steinitz, Wilhelm  Zukertort, Johannes H      0-1
# 2    Zukertort, Johannes H      Steinitz, Wilhelm      1-0
# 3        Steinitz, Wilhelm  Zukertort, Johannes H      0-1
# 4    Zukertort, Johannes H      Steinitz, Wilhelm      1-0
# ..                     ...                    ...      ...
# 680         Kasparov, Gary        Karpov, Anatoly  1/2-1/2
# 681        Karpov, Anatoly         Kasparov, Gary  1/2-1/2
# 682         Kasparov, Gary        Karpov, Anatoly  1/2-1/2
# 683        Karpov, Anatoly         Kasparov, Gary      0-1
# 684         Kasparov, Gary        Karpov, Anatoly      1-0
#
#                                                  Moves
# 0    d2d4 d7d5 c2c4 c7c6 e2e3 c8f5 b1c3 e7e6 g1f3 b...
# 1    e2e4 e7e5 g1f3 b8c6 d2d4 e5d4 f3d4 g8f6 b1c3 f...
# 2    d2d4 d7d5 c2c4 c7c6 e2e3 c8f5 a2a3 e7e6 c4c5 a...
# 3    e2e4 e7e5 g1f3 b8c6 f1b5 g8f6 e1g1 f6e4 f1e1 e...
# 4    d2d4 d7d5 c2c4 c7c6 b1c3 g8f6 e2e3 c8f5 c4d5 c...
# ..                                                 ...
# 680  e2e4 e7e5 g1f3 b8c6 f1b5 a7a6 b5a4 g8f6 e1g1 f...
# 681  e2e4 c7c5 g1f3 d7d6 d2d4 c5d4 f3d4 g8f6 b1c3 a...
# 682  e2e4 e7e5 g1f3 b8c6 f1b5 a7a6 b5a4 g8f6 e1g1 f...
# 683  g1f3 g8f6 c2c4 e7e6 d2d4 d7d5 b1c3 c7c6 c1g5 b...
# 684  e2e4 e7e5 g1f3 g8f6 f3e5 d7d6 e5f3 f6e4 d2d4 d...
#
# [685 rows x 10 columns]

# %% [markdown]
# # 从连接表构建多路有向图

# %%
G = nx.from_pandas_edgelist(df, 'White', 'Black', edge_attr=True, create_using=nx.MultiDiGraph())
print('棋手（节点）个数', G.number_of_nodes())
print('棋局（连接）个数', G.number_of_edges())
# Out:
# 棋手（节点）个数 25
# 棋局（连接）个数 685

# %%
# 所有节点
G.nodes

#所有连接（带特征）
G.edges(data=True)
# Out:
# OutMultiEdgeDataView([('Zukertort, Johannes H', 'Steinitz, Wilhelm', {'Event': 'World Championship 1st', 'Site': 'USA', 'Date': '1886.01.11', 'EventDate': '1886.01.11', 'ECO': 'D11', 'Round': 1, 'Result': '0-1', 'Moves': 'd2d4 d7d5 c2c4 c7c6 e2e3 c8f5 b1c3 e7e6 g1f3 b8d7 a2a3 f8d6 c4c5 d6c7 b2b4 e6e5 f1e2 g8f6 c1b2 e5e4 f3d2 h7h5 h2h3 d7f8 a3a4 f8g6 b4b5 g6h4 g2g3 h4g2 e1f1 g2e3 f2e3 c7g3 f1g2 g3c7 d1g1 h8h6 g2f1 h6g6 g1f2 d8d7 b5c6 b7c6 h1g1 f5h3 f1e1 f6g4 e2g4 h3g4 c3e2 d7e7 e2f4 g6h6 b2c3 g7g5 f4e2 h6f6 f2g2 f6f3 d2f1 a8b8 e1d2 f7f5 a4a5 f5f4 g1h1 e7f7 a1e1 f4e3 f1e3 f3f2 g2f2 f7f2 e3g4 c7f4 d2c2 h5g4 c3d2 e4e3 d2c1 f2g2 c2c3 e8d7 h1h7 d7e6 h7h6 e6f5 c1e3 f4e3 e1f1 e3f4'}), ('Zukertort, Johannes H', 'Steinitz, Wilhelm', {'Event': 'World Championship 1st', 'Site': 'USA', 'Date': '1886.01.15', 'EventDate': '1886.01.11', 'ECO': 'D10', 'Round': 3, 'Result': '1-0', 'Moves': 'd2d4 d7d5 c2c4 c7c6 e2e3 c8f5 a2a3 e7e6 c4c5 a7a5 d1b3 d8c7 b1c3 b8d7 c3a4 g8f6 g1e2 f8e7 e2g3 f5g6 c1d2 e8g8 f1e2 f8b8 e1g1 b7b6 c5b6 d7b6 a4b6 b8b6 b3c3 c7b7 a1a2 f6d7 e2d1 c6c5 d1a4 c5c4 c3c1 d7f6 d2c3 e7d6 f2f3 b7b8 f3f4 g6d3 f1e1 h7h5 h2h4 b8d8 a4d1 g7g6 c1d2 b6b8 d2f2 d6e7 d1f3 f6e4 f3e4 d5e4 g3h1 e7h4 g2g3 h4e7 f2d2 d8d5 h1f2 a5a4 g1g2 b8b3 e1h1 g8g7 a2a1 e7d8 g3g4 h5g4 f2g4 d8a5 h1h7 g7f8 h7h8 f8g7 h8h7 g7f8 d2f2 a5d8 g4e5 f8g8 a1h1 d8f6 h7f7 a8f8 f7f6'}), ('Zukertort, Johannes H', 'Steinitz, Wilhelm', {'Event': 'World Championship 1st', 'Site': 'USA', 'Date': '1886.01.20', 'EventDate': '1886.01.11', 'ECO': 'D10', 'Round': 5, 'Result': '1-0', 'Moves': 'd2d4 d7d5 c2c4 c7c6 b1c3 g8f6 e2e3 c8f5 c4d5 c6d5 d1b3 f5c8 g1f3 b8c6 f3e5 e7e6 f1b5 d8c7 c1d2 f8d6 f2f4 e8g8 a1c1 d6e5 f4e5 f6e8 e1g1 f7f6 b5d3 f8f7 b3c2 f6f5 c3e2 c8d7 f1f2 a8c8 d2c3 c7b6 c2d2 c6e7 c1f1 d7b5 d3b1 b6a6 g2g4 g7g6 h2h3 c8c7 f1e1 e8g7 e2f4 e7c8 g4f5 g6f5 f2g2 g8h8 g1h2 a6c6 e1g1 c8e7 d2f2 c6e8 g2g7'}), ('Zukertort, Johannes H', 'Steinitz, Wilhelm', {'Event': 'World Championship 1st', 'Site': 'USA', 'Date': '1886.02.05', 'EventDate': '1886.01.11', 'ECO': 'D40', 'Round': 7, 'Result': '0-1', 'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 e2e3 c7c5 g1f3 b8c6 a2a3 d5c4 f1c4 c5d4 e3d4 f8e7 e1g1 e8g8 c1e3 c8d7 d1d3 a8c8 a1c1 d8a5 c4a2 f8d8 f1e1 d7e8 a2b1 g7g6 d3e2 e7f8 e1d1 f8g7 b1a2 c6e7 e2d2 a5a6 e3g5 e7f5 g2g4 f5d4 f3d4 e6e5 c3d5 c8c1 d2c1 e5d4 d1d4 f6d5 d4d5 d8d5 a2d5 a6e2 h2h3 h7h6 d5c4 e2f3 c1e3 f3d1 g1h2 e8c6 g5e7 g7e5 f2f4 e5f4 e3f4 d1h1 h2g3 h1g1'}), ('Zukertort, Johannes H', 'Steinitz, Wilhelm', {'Event': 'World Championship 1st', 'Site': 'USA', 'Date': '1886.02.10', 'EventDate': '1886.01.11', 'ECO': 'D26', 'Round': 9, 'Result': '0-1', 'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 g1f3 d5c4 e2e3 c7c5 f1c4 c5d4 e3d4 f8e7 e1g1 e8g8 d1e2 b8d7 c4b3 d7b6 c1f4 b6d5 f4g3 d8a5 a1c1 c8d7 f3e5 f8d8 e2f3 d7e8 f1e1 a8c8 g3h4 d5c3 b2c3 a5c7 f3d3 f6d5 h4e7 c7e7 b3d5 d8d5 c3c4 d5d8 e1e3 e7d6 c1d1 f7f6 e3h3 h7h6 e5g4 d6f4 g4e3 e8a4 h3f3 f4d6 d1d2 a4c6 f3g3 f6f5 g3g6 c6e4 d3b3 g8h7 c4c5 c8c5 g6e6 c5c1 e3d1 d6f4 b3b2 c1b1 b2c3 d8c8 e6e4 f4e4'}), ('Zukertort, Johannes H', 'Steinitz, Wilhelm', {'Event': 'World Championship 1st', 'Site': 'USA', 'Date': '1886.03.01', 'EventDate': '1886.01.11', 'ECO': 'C49', 'Round': 11, 'Result': '0-1', 'Moves': 'e2e4 e7e5 g1f3 b8c6 b1c3 g8f6 f1b5 f8b4 e1g1 e8g8 c3d5 f6d5 e4d5 e5e4 d5c6 e4f3 d1f3 d7c6 b5d3 b4d6 b2b3 d8g5 c1b2 g5d2 b2c1 d2a5 c1f4 c8e6 a1e1 f8e8 e1e3 e6d5 d3h7 g8h7 f3h5 h7g8 e3h3 f7f6 h5h7 g8f7 h7h5 f7f8 h5h8 f8f7 h8h5 f7f8 h5h8 f8f7 h8h5 f7f8 h5h8 f8f7 h8h5 f7f8 h5h8 f8f7 h8h5 f7f8 h5h8 f8f7 h8h5 f7e7 h3e3 e7f8 h5h8 d5g8 f4h6 e8e7 e3e7 f8e7 h6g7 a5f5 f1e1 e7f7 g7h6 f5h7 h8h7 g8h7 c2c4 a7a5 h6e3 c6c5 e1d1 a5a4'}), ('Zukertort, Johannes H', 'Steinitz, Wilhelm', {'Event': 'World Championship 1st', 'Site': 'USA', 'Date': '1886.03.05', 'EventDate': '1886.01.11', 'ECO': 'D26', 'Round': 13, 'Result': '1-0', 'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 c1f4 c7c5 e2e3 c5d4 e3d4 d5c4 f1c4 b8c6 g1f3 f8e7 e1g1 e8g8 f1e1 c8d7 d1e2 d8a5 c3b5 a7a6 f4c7 b7b6 b5c3 f8c8 c7f4 b6b5 c4b3 a5b6 e1 ...

# %%
# 两个棋手的所有棋局
G.get_edge_data('Zukertort, Johannes H', 'Steinitz, Wilhelm')
# Out:
# {0: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.01.11',
#   'EventDate': '1886.01.11',
#   'ECO': 'D11',
#   'Round': 1,
#   'Result': '0-1',
#   'Moves': 'd2d4 d7d5 c2c4 c7c6 e2e3 c8f5 b1c3 e7e6 g1f3 b8d7 a2a3 f8d6 c4c5 d6c7 b2b4 e6e5 f1e2 g8f6 c1b2 e5e4 f3d2 h7h5 h2h3 d7f8 a3a4 f8g6 b4b5 g6h4 g2g3 h4g2 e1f1 g2e3 f2e3 c7g3 f1g2 g3c7 d1g1 h8h6 g2f1 h6g6 g1f2 d8d7 b5c6 b7c6 h1g1 f5h3 f1e1 f6g4 e2g4 h3g4 c3e2 d7e7 e2f4 g6h6 b2c3 g7g5 f4e2 h6f6 f2g2 f6f3 d2f1 a8b8 e1d2 f7f5 a4a5 f5f4 g1h1 e7f7 a1e1 f4e3 f1e3 f3f2 g2f2 f7f2 e3g4 c7f4 d2c2 h5g4 c3d2 e4e3 d2c1 f2g2 c2c3 e8d7 h1h7 d7e6 h7h6 e6f5 c1e3 f4e3 e1f1 e3f4'},
#  1: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.01.15',
#   'EventDate': '1886.01.11',
#   'ECO': 'D10',
#   'Round': 3,
#   'Result': '1-0',
#   'Moves': 'd2d4 d7d5 c2c4 c7c6 e2e3 c8f5 a2a3 e7e6 c4c5 a7a5 d1b3 d8c7 b1c3 b8d7 c3a4 g8f6 g1e2 f8e7 e2g3 f5g6 c1d2 e8g8 f1e2 f8b8 e1g1 b7b6 c5b6 d7b6 a4b6 b8b6 b3c3 c7b7 a1a2 f6d7 e2d1 c6c5 d1a4 c5c4 c3c1 d7f6 d2c3 e7d6 f2f3 b7b8 f3f4 g6d3 f1e1 h7h5 h2h4 b8d8 a4d1 g7g6 c1d2 b6b8 d2f2 d6e7 d1f3 f6e4 f3e4 d5e4 g3h1 e7h4 g2g3 h4e7 f2d2 d8d5 h1f2 a5a4 g1g2 b8b3 e1h1 g8g7 a2a1 e7d8 g3g4 h5g4 f2g4 d8a5 h1h7 g7f8 h7h8 f8g7 h8h7 g7f8 d2f2 a5d8 g4e5 f8g8 a1h1 d8f6 h7f7 a8f8 f7f6'},
#  2: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.01.20',
#   'EventDate': '1886.01.11',
#   'ECO': 'D10',
#   'Round': 5,
#   'Result': '1-0',
#   'Moves': 'd2d4 d7d5 c2c4 c7c6 b1c3 g8f6 e2e3 c8f5 c4d5 c6d5 d1b3 f5c8 g1f3 b8c6 f3e5 e7e6 f1b5 d8c7 c1d2 f8d6 f2f4 e8g8 a1c1 d6e5 f4e5 f6e8 e1g1 f7f6 b5d3 f8f7 b3c2 f6f5 c3e2 c8d7 f1f2 a8c8 d2c3 c7b6 c2d2 c6e7 c1f1 d7b5 d3b1 b6a6 g2g4 g7g6 h2h3 c8c7 f1e1 e8g7 e2f4 e7c8 g4f5 g6f5 f2g2 g8h8 g1h2 a6c6 e1g1 c8e7 d2f2 c6e8 g2g7'},
#  3: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.02.05',
#   'EventDate': '1886.01.11',
#   'ECO': 'D40',
#   'Round': 7,
#   'Result': '0-1',
#   'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 e2e3 c7c5 g1f3 b8c6 a2a3 d5c4 f1c4 c5d4 e3d4 f8e7 e1g1 e8g8 c1e3 c8d7 d1d3 a8c8 a1c1 d8a5 c4a2 f8d8 f1e1 d7e8 a2b1 g7g6 d3e2 e7f8 e1d1 f8g7 b1a2 c6e7 e2d2 a5a6 e3g5 e7f5 g2g4 f5d4 f3d4 e6e5 c3d5 c8c1 d2c1 e5d4 d1d4 f6d5 d4d5 d8d5 a2d5 a6e2 h2h3 h7h6 d5c4 e2f3 c1e3 f3d1 g1h2 e8c6 g5e7 g7e5 f2f4 e5f4 e3f4 d1h1 h2g3 h1g1'},
#  4: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.02.10',
#   'EventDate': '1886.01.11',
#   'ECO': 'D26',
#   'Round': 9,
#   'Result': '0-1',
#   'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 g1f3 d5c4 e2e3 c7c5 f1c4 c5d4 e3d4 f8e7 e1g1 e8g8 d1e2 b8d7 c4b3 d7b6 c1f4 b6d5 f4g3 d8a5 a1c1 c8d7 f3e5 f8d8 e2f3 d7e8 f1e1 a8c8 g3h4 d5c3 b2c3 a5c7 f3d3 f6d5 h4e7 c7e7 b3d5 d8d5 c3c4 d5d8 e1e3 e7d6 c1d1 f7f6 e3h3 h7h6 e5g4 d6f4 g4e3 e8a4 h3f3 f4d6 d1d2 a4c6 f3g3 f6f5 g3g6 c6e4 d3b3 g8h7 c4c5 c8c5 g6e6 c5c1 e3d1 d6f4 b3b2 c1b1 b2c3 d8c8 e6e4 f4e4'},
#  5: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.03.01',
#   'EventDate': '1886.01.11',
#   'ECO': 'C49',
#   'Round': 11,
#   'Result': '0-1',
#   'Moves': 'e2e4 e7e5 g1f3 b8c6 b1c3 g8f6 f1b5 f8b4 e1g1 e8g8 c3d5 f6d5 e4d5 e5e4 d5c6 e4f3 d1f3 d7c6 b5d3 b4d6 b2b3 d8g5 c1b2 g5d2 b2c1 d2a5 c1f4 c8e6 a1e1 f8e8 e1e3 e6d5 d3h7 g8h7 f3h5 h7g8 e3h3 f7f6 h5h7 g8f7 h7h5 f7f8 h5h8 f8f7 h8h5 f7f8 h5h8 f8f7 h8h5 f7f8 h5h8 f8f7 h8h5 f7f8 h5h8 f8f7 h8h5 f7f8 h5h8 f8f7 h8h5 f7e7 h3e3 e7f8 h5h8 d5g8 f4h6 e8e7 e3e7 f8e7 h6g7 a5f5 f1e1 e7f7 g7h6 f5h7 h8h7 g8h7 c2c4 a7a5 h6e3 c6c5 e1d1 a5a4'},
#  6: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.03.05',
#   'EventDate': '1886.01.11',
#   'ECO': 'D26',
#   'Round': 13,
#   'Result': '1-0',
#   'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 c1f4 c7c5 e2e3 c5d4 e3d4 d5c4 f1c4 b8c6 g1f3 f8e7 e1g1 e8g8 f1e1 c8d7 d1e2 d8a5 c3b5 a7a6 f4c7 b7b6 b5c3 f8c8 c7f4 b6b5 c4b3 a5b6 e1d1 c6a5 b3c2 a5c4 c2d3 c4d6 f3e5 d7e8 f4g5 b6d8 e2f3 a8a7 f3h3 h7h6 g5e3 a7c7 d4d5 b5b4 c3e2 f6d5 d3a6 c8a8 a6d3 e7f6 e3d4 d6b5 e5f3 b5d4 f3d4 a8a5 h3f3 e8a4 d1e1 d5e7 f3e4 g7g6 b2b3 a4e8 d3c4 e7f5 d4e6 f7e6 c4e6 g8g7 a1d1 d8e7 e2f4 a5e5 e4b1 e5e1 d1e1 f6c3 f4d5 e7c5 d5c7 c5c7 e1d1 f5d4 e6c4 e8c6 b1d3 c6a8 d3e3 c7d6 a2a3 a8c6 a3b4 d6f6 g1f1 d4b5 e3e6 f6e6 c4e6 c3b4 e6d7 b5c3 d1d4 c6d7 d4d7 g7f6 d7d4 b4e7 b3b4 f6e5 d4c4 c3b5 c4c6 e7d6 c6b6 b5d4 b6b7 g6g5 b4b5 e5d5 b5b6 d5c6 b7h7 c6b6 h7h6 b6c7 h2h4 g5h4 h6h4 d4f5 h4h7 c7d8 g2g4 f5e7 f1g2 d8e8 g2f3 d6c5 h7h5 c5d4 f3g3 e8f7 f2f4 d4c3 h5b5 c3e1 g3f3 e1c3 g4g5 c3a1 f3g4 a1c3 f4f5 c3d4 b5b7 d4c3 g4h5 c3d4 h5h6 d4g7 h6h7 g7e5 g5g6 f7f8 b7e7'},
#  7: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.03.15',
#   'EventDate': '1886.01.11',
#   'ECO': 'D50',
#   'Round': 15,
#   'Result': '1/2-1/2',
#   'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 c1g5 c7c5 c4d5 e6d5 g5f6 g7f6 e2e3 c8e6 d1b3 d8d7 f1b5 b8c6 e3e4 e8c8 e4d5 e6d5 c3d5 d7d5 b3d5 d8d5 b5c6 b7c6 d4c5 f8c5 g1f3 h8e8 e1f1 c5b6 g2g3 d5f5 f1g2 e8e2 h1f1 e2b2 a2a4 f5c5 f3g1 c5a5 a1a3 c8b7 g1h3 b6d4 f1e1 a5e5 e1d1 c6c5 a3f3 e5e2 d1f1 b2b6 h3f4 e2a2 f4d5 b6e6 d5f4 e6d6 f1b1 b7c6 b1b8 a2a4 b8h8 a4a2 h8h7 a7a5 h7f7 a5a4 h2h4 d6d7 f7d7 c6d7 h4h5 d7e7 h5h6 e7f7 h6h7 f7g7 f4e6 g7h7 e6d4 c5d4 f3d3 a2b2 d3d4 a4a3 d4a4 a3a2 g3g4 h7g6 g2g3 g6f7 f2f4'},
#  8: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.03.19',
#   'EventDate': '1886.01.11',
#   'ECO': 'D60',
#   'Round': 17,
#   'Result': '1/2-1/2',
#   'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 c1g5 f8e7 g1f3 e8g8 e2e3 d5c4 f1c4 b8d7 e1g1 c7c5 d1e2 h7h6 g5h4 d7b6 d4c5 e7c5 f1d1 b6d7 e3e4 c5e7 e4e5 f6e8 h4g3 d8b6 a2a3 a7a5 a1c1 d7c5 g3f4 c8d7 f4e3 d7c6 f3d4 a8d8 d4b5 d8d1 c1d1 c6b5 c3b5 b6c6 b2b4 a5b4 a3b4 c5d7 b5d4 c6e4 d4e6 d7e5 e6f8 e5c4 f8d7 e7b4 e2d3 e4g4 h2h3 g4e6 d1b1 c4e3 d3e3 e6d7 b1b4 d7d1 g1h2 d1d6 e3f4 g8f8 f4d6 e8d6 h2g3 f8e7 g3f4 e7e6 h3h4 e6d5 g2g4 b7b5 b4b1 d5c5 b1c1 c5d5 f4e3 d6c4 e3e2 b5b4 c1b1 d5c5 f2f4 c4a3 b1c1 c5d4 c1c7 b4b3 c7b7 d4c3 b7c7 c3d4 c7b7 d4c3'},
#  9: {'Event': 'World Championship 1st',
#   'Site': 'USA',
#   'Date': '1886.03.24',
#   'EventDate': '1886.01.11',
#   'ECO': 'D53',
#   'Round': 19,
#   'Result': '0-1',
#   'Moves': 'd2d4 d7d5 c2c4 e7e6 b1c3 g8f6 c1g5 f8e7 g1f3 e8g8 c4c5 b7b6 b2b4 b6c5 d4c5 a7a5 a2a3 d5d4 g5f6 g7f6 c3a4 e6e5 b4b5 c8e6 g2g3 c7c6 b5c6 b8c6 f1g2 a8b8 d1c1 d4d3 e2e3 e5e4 f3d2 f6f5 e1g1 f8e8 f2f3 c6d4 e3d4 d8d4 g1h1 e4e3 a4c3 e7f6 d2b1 d3d2 c1c2 e6b3 c2f5 d2d1q c3d1 b3d1 b1c3 e3e2 a1d1 d4c3'}}

# %% [markdown]
# # 初步可视化

# %%
pos = nx.spring_layout(G, seed=10)
nx.draw(G, pos)

# %% [markdown]
# # 连通域分析

# %%
# 将G转为无向图，分析连通域
H = G.to_undirected()
for each in nx.connected_components(H):
    print('连通域')
    print(H.subgraph(each))
    print('包含节点')
    print(each)
    print('\n')
# Out:
# 连通域
# MultiGraph with 22 nodes and 304 edges
# 包含节点
# {'Lasker, Emanuel', 'Schlechter, Carl', 'Janowski, Dawid M', 'Alekhine, Alexander A', 'Petrosian, Tigran V', 'Gunsberg, Isidor A', 'Marshall, Frank J', 'Bronstein, David I', 'Fischer, Robert J', 'Smyslov, Vassily V', 'Botvinnik, Mikhail M', 'Chigorin, Mikhail I', 'Bogoljubow, Efim D', 'Spassky, Boris V', 'Tal, Mikhail N', 'Keres, Paul', 'Capablanca, Jose Raul', 'Tarrasch, Siegbert', 'Zukertort, Johannes H', 'Steinitz, Wilhelm', 'Reshevsky, Samuel H', 'Euwe, Max'}
#
#
# 连通域
# MultiGraph with 3 nodes and 49 edges
# 包含节点
# {'Kasparov, Gary', 'Karpov, Anatoly', 'Korchnoi, Viktor L'}

# %% [markdown]
# # 高级可视化

# %%
# 将G转为无向-单连接图
H = nx.Graph(G)

# %%
# 两个棋手的所有棋局
len(G.get_edge_data('Zukertort, Johannes H', 'Steinitz, Wilhelm'))
# Out:
# 10

# %%
import scipy
# 两个棋手节点之间的 连接宽度 与 棋局个数 成正比
edgewidth = [len(G.get_edge_data(u, v)) for u, v in H.edges()]
# 棋手节点的大小 与 赢棋次数 成正比
wins = dict.fromkeys(G.nodes(), 0) # 生成每个棋手作为key的dict
for (u, v, d) in G.edges(data=True):
    r = d["Result"].split("-")
    if r[0] == "1":
        wins[u] += 1.0
    elif r[0] == "1/2":
        wins[u] += 0.5
        wins[v] += 0.5
    else:
        wins[v] += 1.0
nodesize = [wins[v] * 50 for v in H]

# 布局
pos = nx.kamada_kawai_layout(H)

# 手动微调节点的横坐标（越大越靠右）、纵坐标（越大越靠下）
pos["Reshevsky, Samuel H"] += (0.05, -0.10)
pos["Botvinnik, Mikhail M"] += (0.03, -0.06)
pos["Smyslov, Vassily V"] += (0.05, -0.03)

fig, ax = plt.subplots(figsize=(12, 12))

# 可视化连接
nx.draw_networkx_edges(H, pos, alpha=0.3, width=edgewidth, edge_color="m")

# 可视化节点
nx.draw_networkx_nodes(H, pos, node_size=nodesize, node_color="#210070", alpha=0.9)

# 节点名称文字说明
label_options = {"ec": "k", "fc": "white", "alpha": 0.7}
nx.draw_networkx_labels(H, pos, font_size=14, bbox=label_options)

# 标题和图例
font = {"fontname": "sans-serif", "color": "k", "fontweight": "bold", "fontsize": 16}
ax.set_title("World Chess Championship Games: 1886 - 1985", font)
# 图例字体颜色
font["color"] = "r"

# 文字说明
ax.text(
    0.80,
    0.10,
    "edge width = # games played",
    horizontalalignment="center",
    transform=ax.transAxes,
    fontdict=font,
)
ax.text(
    0.80,
    0.06,
    "node size = # games won",
    horizontalalignment="center",
    transform=ax.transAxes,
    fontdict=font,
)

# 调整图的大小，提高可读性
ax.margins(0.1, 0.05)
fig.tight_layout()
plt.axis("off")
plt.show()
