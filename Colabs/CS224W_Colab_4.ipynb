# %% [markdown]
# # **CS224W - Colab 4**

# %% [markdown]
# In this Colab, we will shift our focus from homogenous graphs to heterogeneous graphs（同构图到异构图）. Heterogeneous graphs extend the traditional homogenous graphs that we have seen before by specifically incorperating different node and edge types. This additional information allows us to extend the graph neural nework models that we have worked with before. Namely, we can apply heterogenous message passing, where different message types now exist between different node, edge type relationships.
#
# 异构图在传统同构图的基础上进行了拓展，专门引入了不同的节点类型与边类型。这类额外信息能够进一步优化现有图神经网络模型。具体而言，我们可以采用异质消息传递机制，在不同节点与边类型的关联关系之间，建立多种不同类型的消息传递方式。
#
# At first, we will learn how to transform NetworkX graphs into DeepSNAP representations. Additionally, we will dive deeper into how DeepSNAP stores and represents heterogeneous graphs as PyTorch Tensors.
#
# Then, we will build our own heterogenous graph neural netowrk models using PyTorch Geonetric and DeepSNAP on node property prediction task. To evaluate these models, we will use our model on the heterogeneous ACM dataset.
#
# **Note**: Make sure to **sequentially run all the cells in each section**, so that the intermediate variables / packages will carry over to the next cell
#
# Have fun on Colab 4 :)

# %% [markdown]
# # Device
# You might need to use GPU for this Colab.
#
# Please click `Runtime` and then `Change runtime type`. Then set the `hardware accelerator` to **GPU**.

# %% [markdown]
# # Installation

# %%
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-geometric
# !pip install -q git+https://github.com/snap-stanford/deepsnap.git
# !pip install -U -q PyDrive
# Out:
# ^C

# %%
import torch_geometric
torch_geometric.__version__
# Out:
# '2.6.1'

# %% [markdown]
# # 1 DeepSNAP Heterogeneous Graph
#
# First, we will explore how to transform NetworkX graphs into the format supported by DeepSNAP.
#
# In order to extend the traditional DeepSNAP representation of graphs to include heterogenous graphs, we include the following graph property features:
# * `node_feature`: The feature of each node (`torch.tensor`)
# * `edge_feature`: The feautre of each edge (`torch.tensor`)
# * `node_label`: The label of each node (`int`)
# * `node_type`: The node type of each node (`string`)
# * `edge_type`: The edge type of each edge (`string`)
#
# 为将传统 DeepSNAP 图表示形式拓展至异构图，我们引入以下图属性特征：
# node_feature：每个节点的特征（torch.tensor）
# edge_feature：每条边的特征（torch.tensor）
# node_label：每个节点的标签（int）
# node_type：每个节点的类型（string）
# edge_type：每条边的类型（string）
#
# The key new features we add are `node_type` and `edge_type`, which enables us to perform heterogenous message passing.
#
# In this first question we will work with the familiar [karate club graph](https://networkx.github.io/documentation/stable/auto_examples/graph/plot_karate_club.html) seen in assignment one. To start, since each node in the graph belongs to one of two clubs (club "Mr. Hi" or club "Officer"), we will treat the club as the `node_type`. The code below demonstrates how to differentiate the nodes in the NetworkX graph.
#
# 我们新增的核心功能为node_type与edge_type，借此可实现异质消息传递。
# 在本第一道问题中，我们将使用作业一中接触过的经典空手道俱乐部图开展实验。首先，该图中的每个节点分属两个俱乐部之一（“Hi 先生” 俱乐部或 “官员” 俱乐部），我们将俱乐部归属定义为node_type。下方代码演示了如何在 NetworkX 图结构中对节点进行类型区分。

# %%
from pylab import *
import networkx as nx
from networkx.algorithms.community import greedy_modularity_communities
import matplotlib.pyplot as plt
import copy

G = nx.karate_club_graph()
community_map = {}
for node in G.nodes(data=True):
  if node[1]["club"] == "Mr. Hi":
    community_map[node[0]] = 0
  else:
    community_map[node[0]] = 1
node_color = []
color_map = {0: 0, 1: 1}
node_color = [color_map[community_map[node]] for node in G.nodes()]
pos = nx.spring_layout(G)
plt.figure(figsize=(7, 7))
nx.draw(G, pos=pos, cmap=plt.get_cmap('coolwarm'), node_color=node_color)
show()

# %% [markdown]
# ### Question 1.1: Assigning Node Type and Node Features (Not Specifically Graded)
#
# 问题 1.1：节点类型与节点特征分配（不计入专项评分）
#
# Using the `community_map` dictionary and graph `G` from above, add node attributes `node_type` and `node_label` to the graph G. Namely, for `node_type` assign nodes in the "Mr. Hi" club to a node type `n0` and nodes in club "Officer" a node type `n1`.
#
# Then for `node_label`, assign nodes in "Mr. Hi" club to a `node_label` `0` and nodes in club "Officer" a `node_label` of `1`.
#
# Lastly, assign every node a feature vector [1, 1, 1, 1, 1].
#
# **Hint**: Look at the NetworkX function `nx.classes.function.set_node_attributes`.
#
# **Note**: This question is not specifically graded but is important for later questions.
#
# 使用上文的community_map字典与图G，为图G添加节点属性node_type和node_label。具体规则如下：
#
# 对于node_type，将「Hi 先生」社团内的节点赋值为节点类型n0，将「官员」社团内的节点赋值为节点类型n1。
#
# 对于node_label，将「Hi 先生」社团内的节点赋值为标签0，将「官员」社团内的节点赋值为标签1。
#
# 最后，为所有节点统一分配特征向量 [1, 1, 1, 1, 1]。
#
# 提示：可参考 NetworkX 内置函数 nx.classes.function.
# set_node_attributes。

# %%
import torch

def assign_node_types(G, community_map):
  # TODO: Implement this function that takes in a NetworkX graph
  # G and community map assignment (mapping node ids --> 0/1 labels)
  # and adds 'node_type' as a node_attribute in G.

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Look up NetworkX `nx.classes.function.set_node_attributes`

  # 将 0/1 转换为 'n0'/'n1'
  node_types_dict = {node: f"n{label}" for node, label in community_map.items()}
  nx.set_node_attributes(G, node_types_dict, 'node_type')

  #########################################

def assign_node_labels(G, community_map):
  # TODO: Implement this function that takes in a NetworkX graph
  # G and community map assignment (mapping node ids --> 0/1 labels)
  # and adds 'node_label' as a node_attribute in G.

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Look up NetworkX `nx.classes.function.set_node_attributes`
  
  nx.set_node_attributes(G, community_map, 'node_label')

  #########################################

def assign_node_features(G):
  # TODO: Implement this function that takes in a NetworkX graph
  # G and adds 'node_feature' as a node_attribute in G. Each node
  # in the graph has the same feature vector [1., 1., 1., 1., 1.]

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Look up NetworkX `nx.classes.function.set_node_attributes`
  
  nx.set_node_attributes(G, {node: torch.tensor([1., 1., 1., 1., 1.]) for node in G.nodes()}, 'node_feature')

  #########################################

assign_node_types(G, community_map)
assign_node_labels(G, community_map)
assign_node_features(G)

G.nodes(data=True)
# Out:
# NodeDataView({0: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 1: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 2: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 3: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 4: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 5: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 6: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 7: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 8: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 9: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 10: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 11: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 12: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 13: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 14: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 15: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 16: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 17: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 18: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 19: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 20: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 21: {'club': 'Mr. Hi', 'node_type': 'n0', 'node_label': 0, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 22: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 23: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 24: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 25: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 26: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 27: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 28: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 29: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 30: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 31: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 32: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}, 33: {'club': 'Officer', 'node_type': 'n1', 'node_label': 1, 'node_feature': tensor([1., 1., 1., 1., 1.])}})

# %% [markdown]
# ### Question 1.2: Assigning Edge Types (Not Specifically Graded)
# 问题 1.2：边类型分配（非特定分级）
#
# Next, we will assign three different types of `edge_type` to the edges:
# * Edges within club "Mr. Hi": `e0`
# * Edges within club "Officer": `e1`
# * Edges between clubs: `e2`
#
# **Hint**: Use the `community_map` from before and `nx.classes.function.set_edge_attributes`

# %%
def assign_edge_types(G, community_map):
  # TODO: Implement this function that takes in a NetworkX graph
  # G and community map assignment (mapping node ids --> 0/1 labels)
  # and adds 'edge_type' as a edge_attribute in G.

  ############# Your code here ############
  ## (~5 line of code)
  ## Note
  ## 1. Create an edge assignment dict following rules above
  
  edge_types_dict = {}
  for u, v in G.edges():
      if community_map[u] == community_map[v]:
          # 同一个社团，类型为 e0 或 e1
          edge_types_dict[(u, v)] = f"e{community_map[u]}"
      else:
          # 跨社团，类型为 e2
          edge_types_dict[(u, v)] = 'e2'
          
  nx.set_edge_attributes(G, edge_types_dict, 'edge_type')
  #########################################

assign_edge_types(G, community_map)
G.edges(data=True)
# Out:
# EdgeDataView([(0, 1, {'weight': 4, 'edge_type': 'e0'}), (0, 2, {'weight': 5, 'edge_type': 'e0'}), (0, 3, {'weight': 3, 'edge_type': 'e0'}), (0, 4, {'weight': 3, 'edge_type': 'e0'}), (0, 5, {'weight': 3, 'edge_type': 'e0'}), (0, 6, {'weight': 3, 'edge_type': 'e0'}), (0, 7, {'weight': 2, 'edge_type': 'e0'}), (0, 8, {'weight': 2, 'edge_type': 'e0'}), (0, 10, {'weight': 2, 'edge_type': 'e0'}), (0, 11, {'weight': 3, 'edge_type': 'e0'}), (0, 12, {'weight': 1, 'edge_type': 'e0'}), (0, 13, {'weight': 3, 'edge_type': 'e0'}), (0, 17, {'weight': 2, 'edge_type': 'e0'}), (0, 19, {'weight': 2, 'edge_type': 'e0'}), (0, 21, {'weight': 2, 'edge_type': 'e0'}), (0, 31, {'weight': 2, 'edge_type': 'e2'}), (1, 2, {'weight': 6, 'edge_type': 'e0'}), (1, 3, {'weight': 3, 'edge_type': 'e0'}), (1, 7, {'weight': 4, 'edge_type': 'e0'}), (1, 13, {'weight': 5, 'edge_type': 'e0'}), (1, 17, {'weight': 1, 'edge_type': 'e0'}), (1, 19, {'weight': 2, 'edge_type': 'e0'}), (1, 21, {'weight': 2, 'edge_type': 'e0'}), (1, 30, {'weight': 2, 'edge_type': 'e2'}), (2, 3, {'weight': 3, 'edge_type': 'e0'}), (2, 7, {'weight': 4, 'edge_type': 'e0'}), (2, 8, {'weight': 5, 'edge_type': 'e0'}), (2, 9, {'weight': 1, 'edge_type': 'e2'}), (2, 13, {'weight': 3, 'edge_type': 'e0'}), (2, 27, {'weight': 2, 'edge_type': 'e2'}), (2, 28, {'weight': 2, 'edge_type': 'e2'}), (2, 32, {'weight': 2, 'edge_type': 'e2'}), (3, 7, {'weight': 3, 'edge_type': 'e0'}), (3, 12, {'weight': 3, 'edge_type': 'e0'}), (3, 13, {'weight': 3, 'edge_type': 'e0'}), (4, 6, {'weight': 2, 'edge_type': 'e0'}), (4, 10, {'weight': 3, 'edge_type': 'e0'}), (5, 6, {'weight': 5, 'edge_type': 'e0'}), (5, 10, {'weight': 3, 'edge_type': 'e0'}), (5, 16, {'weight': 3, 'edge_type': 'e0'}), (6, 16, {'weight': 3, 'edge_type': 'e0'}), (8, 30, {'weight': 3, 'edge_type': 'e2'}), (8, 32, {'weight': 3, 'edge_type': 'e2'}), (8, 33, {'weight': 4, 'edge_type': 'e2'}), (9, 33, {'weight': 2, 'edge_type': 'e1'}), (13, 33, {'weight': 3, 'edge_type': 'e2'}), (14, 32, {'weight': 3, 'edge_type': 'e1'}), (14, 33, {'weight': 2, 'edge_type': 'e1'}), (15, 32, {'weight': 3, 'edge_type': 'e1'}), (15, 33, {'weight': 4, 'edge_type': 'e1'}), (18, 32, {'weight': 1, 'edge_type': 'e1'}), (18, 33, {'weight': 2, 'edge_type': 'e1'}), (19, 33, {'weight': 1, 'edge_type': 'e2'}), (20, 32, {'weight': 3, 'edge_type': 'e1'}), (20, 33, {'weight': 1, 'edge_type': 'e1'}), (22, 32, {'weight': 2, 'edge_type': 'e1'}), (22, 33, {'weight': 3, 'edge_type': 'e1'}), (23, 25, {'weight': 5, 'edge_type': 'e1'}), (23, 27, {'weight': 4, 'edge_type': 'e1'}), (23, 29, {'weight': 3, 'edge_type': 'e1'}), (23, 32, {'weight': 5, 'edge_type': 'e1'}), (23, 33, {'weight': 4, 'edge_type': 'e1'}), (24, 25, {'weight': 2, 'edge_type': 'e1'}), (24, 27, {'weight': 3, 'edge_type': 'e1'}), (24, 31, {'weight': 2, 'edge_type': 'e1'}), (25, 31, {'weight': 7, 'edge_type': 'e1'}), (26, 29, {'weight': 4, 'edge_type': 'e1'}), (26, 33, {'weight': 2, 'edge_type': 'e1'}), (27, 33, {'weight': 4, 'edge_type': 'e1'}), (28, 31, {'weight': 2, 'edge_type': 'e1'}), (28, 33, {'weight': 2, 'edge_type': 'e1'}), (29, 32, {'weight': 4, 'edge_type': 'e1'}), (29, 33, {'weight': 2, 'edge_type': 'e1'}), (30, 32, {'weight': 3, 'edge_type': 'e1'}), (30, 33, {'weight': 3, 'edge_type': 'e1'}), (31, 32, {'weight': 4, 'edge_type': 'e1'}), (31, 33, {'weight': 4, 'edge_type': 'e1'}), (32, 33, {'weight': 5, 'edge_type': 'e1'})])

# %% [markdown]
# ## Heterogeneous Graph Visualization
#
# Now we can visualize the Heterogeneous Graph we have generated.

# %%
edge_color = {}
for edge in G.edges():
  n1, n2 = edge
  edge_color[edge] = community_map[n1] if community_map[n1] == community_map[n2] else 2
  if community_map[n1] == community_map[n2] and community_map[n1] == 0:
    edge_color[edge] = 'blue'
  elif community_map[n1] == community_map[n2] and community_map[n1] == 1:
    edge_color[edge] = 'red'
  else:
    edge_color[edge] = 'green'

G_orig = copy.deepcopy(G)
nx.classes.function.set_edge_attributes(G, edge_color, name='color')
colors = nx.get_edge_attributes(G,'color').values()
labels = nx.get_node_attributes(G, 'node_type')
plt.figure(figsize=(8, 8))
nx.draw(G, pos=pos, cmap=plt.get_cmap('coolwarm'), node_color=node_color, edge_color=colors, labels=labels, font_color='white')
show()

# %% [markdown]
# which include edges within each clubs (2 types) and edges across two clubs (1 type). Different types of nodes and edges are visualized in different colors. The NetworkX object `G` in following code can be transformed into `deepsnap.hetero_graph.HeteroGraph` directly.
#
# 其中包含社团内部边（共 2 种）与跨社团边（共 1 种）。不同类型的节点和边会以不同颜色可视化展示。下方代码中的 NetworkX 对象 G 可直接转换为 deepsnap.hetero_graph.HeteroGraph。

# %% [markdown]
# ## Transforming to DeepSNAP representation
#
# The NetworkX object `G` in following code can be transformed into `deepsnap.hetero_graph.HeteroGraph` directly!

# %%
from deepsnap.hetero_graph import HeteroGraph

hete = HeteroGraph(G_orig)

# %% [markdown]
# ## Question 1.3: How many nodes are of each type (10 Points)
#
# Submit your answers on Gradescope.

# %%
def get_nodes_per_type(hete):
  # TODO: Implement this function that takes a DeepSNAP dataset object
  # and return the number of nodes per `node_type`.

  num_nodes_n0 = 0
  num_nodes_n1 = 0

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Colab autocomplete functionality might be useful.

  num_nodes_n0 = hete.num_nodes('n0')
  num_nodes_n1 = hete.num_nodes('n1')

  #########################################

  return num_nodes_n0, num_nodes_n1

num_nodes_n0, num_nodes_n1 = get_nodes_per_type(hete)
print("Node type n0 has {} nodes".format(num_nodes_n0))
print("Node type n1 has {} nodes".format(num_nodes_n1))
# Out:
# Node type n0 has 17 nodes
# Node type n1 has 17 nodes

# %% [markdown]
# ## Question 1.4: Message Types: How many edges are of each message type (10 Points)
#
# Submit your answers on Gradescope.
#
# When working with heterogenous graphs, as we have discussed before, we now work with heterogenous message types (i.e. different message types for `node_type` and `edge_type` combinations). For example, an edge of type `e0` connecting two nodes in club "Mr. HI" would have a message type of (`n0`, `e0`, `n0`). In this problem we will analyze how many edges in our graph are of each message type.
#
# **Hint**: If you want to learn more about what the different message types are try the call `hete.message_types`

# %%
def get_num_message_edges(hete):
  # TODO: Implement this function that takes a DeepSNAP dataset object
  # and return the number of edges for each message type.
  # You should return a list of tuples as
  # (message_type, num_edge)

  message_type_edges = []

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Colab autocomplete functionality might be useful.


  for message_type in hete.message_types:
      num_edges = hete.num_edges(message_type)
      message_type_edges.append((message_type, num_edges))

  #########################################

  return message_type_edges

message_type_edges = get_num_message_edges(hete)
for (message_type, num_edges) in message_type_edges:
  print("Message type {} has {} edges".format(message_type, num_edges))
# Out:
# Message type ('n0', 'e0', 'n0') has 35 edges
# Message type ('n0', 'e2', 'n1') has 11 edges
# Message type ('n1', 'e1', 'n1') has 32 edges

# %% [markdown]
# ## Question 1.5: Dataset Splitting: How many nodes in each dataset split? (10 Points)
#
# Submit your answers on Gradescope.
#
# DeepSNAP has built in Dataset creation and splitting methods for heterogeneous graphs. Here we will create train, validation, and test datasets for a node prediction task and inspect the resulting subgraphs. Specifically, write a function that computes the number of nodes in each dataset split.
#
# DeepSNAP 内置了异构图的数据集构建与划分方法。本文将为节点预测任务创建训练集、验证集与测试集，并查看生成的子图。具体需求为编写一个函数，用于计算每个划分数据集内的节点数量

# %%
from deepsnap.dataset import GraphDataset

def compute_dataset_split_counts(datasets):
  # TODO: Implement this function that takes a dict of datasets
  # and returns a dict mapping dataset names to the number of labeled
  # nodes used for supervision in that respective dataset.

  data_set_splits = {}

  ############# Your code here ############
  ## (~3 line of code)
  ## Note
  ## 1. DeepSNAP `node_label_index` will be helpful.
  ## 2. Remember to count both node_types

  for dataset_name, dataset in datasets.items():
      data_set_splits[dataset_name] = sum([len(inds) for inds in dataset[0].node_label_index.values()])

  #########################################

  return data_set_splits


dataset = GraphDataset([hete], task='node')
# Splitting the dataset
dataset_train, dataset_val, dataset_test = dataset.split(transductive=True, split_ratio=[0.4, 0.3, 0.3])
datasets = {'train': dataset_train, 'val': dataset_val, 'test': dataset_test}

data_set_splits = compute_dataset_split_counts(datasets)
for dataset_name, num_nodes in data_set_splits.items():
  print("{} dataset has {} nodes".format(dataset_name, num_nodes))
# Out:
# train dataset has 12 nodes
# val dataset has 10 nodes
# test dataset has 12 nodes

# %% [markdown]
# ## DeepSNAP Dataset Visualization

# %%
from deepsnap.dataset import GraphDataset

dataset = GraphDataset([hete], task='node')
# Splitting the dataset
dataset_train, dataset_val, dataset_test = dataset.split(transductive=True, split_ratio=[0.4, 0.3, 0.3])
titles = ['Train', 'Validation', 'Test']

for i, dataset in enumerate([dataset_train, dataset_val, dataset_test]):
  n0 = hete._convert_to_graph_index(dataset[0].node_label_index['n0'], 'n0').tolist()
  n1 = hete._convert_to_graph_index(dataset[0].node_label_index['n1'], 'n1').tolist()

  plt.figure(figsize=(7, 7))
  plt.title(titles[i])
  nx.draw(G_orig, pos=pos, node_color="grey", edge_color=colors, labels=labels, font_color='white')
  nx.draw_networkx_nodes(G_orig.subgraph(n0), pos=pos, node_color="blue")
  nx.draw_networkx_nodes(G_orig.subgraph(n1), pos=pos, node_color="red")
  show()

# %% [markdown]
# # 2 Heterogeneous Graph Node Property Prediction
#
# In this part we will use PyTorch Geometric and DeepSNAP to implement a GNN model for heterogeneous graph node property prediction (node classification). This part of Colab requires you having good understandings on the heterogeneous graph and how to implement the GNN layers by using PyG.
#
# At first let's take look at the general structure of a heterogeneous layer by an example.
#
# Let's assume we have a graph $G$, which contains two node types $a$ and $b$, and three message types $m_1=(a, r_1, a)$, $m_2=(a, r_2, b)$ and $m_3=(a, r_3, b)$.
#
# Thus, for $G$ a heterogeneous layer will contains three Heterogeneous GNN layers (`HeteroGNNConv` in this Colab) where each `HeteroGNNConv` layer will perform the message passing and aggregation with respect to only one message type. The overview of the heterogeneous layer is shown below:
#
# <br/>
# <center>
# <img src="https://web.stanford.edu/class/cs224w/images/colab4/hetero_conv.png"/>
# </center>
# <br/>
#
# In this Colab, all the $l^{th}$ Heterogeneous GNN layers will be managed by a ($l^{th}$) Heterogeneous GNN Wrapper layer (the `HeteroGNNWrapperConv`). The $l^{th}$ Heterogeneous GNN Wrapper layer will take in the input node embeddings from $(l-1)^{th}$ layer and aggregate (across message types) the Heterogeneous GNN layers' results. For example, the wrapper layer will aggregate node type $b$'s node embeddings from Heterogeneous GNN layers for $m_2$ and $m_3$. The "simplified" heterogeneous layer structure is shown below:
#
# <br/>
# <center>
# <img src="http://web.stanford.edu/class/cs224w/images/colab4/hetero_conv_1.png"/>
# </center>
# <br/>

# %% [markdown]
# <font color='red'>We recommend you implement the heterogeneous GNN model in following steps:</font>
#
# 1. Implement the `HeteroGNNConv` first.
# 2. Implement the `mean` aggregation in `HeteroGNNWrapperConv`.
# 3. Implement the `generate_convs`.
# 4. Implement the `HeteroGNN` model and the `train` function.
# 5. Train the model with `mean` aggregation across the message types and make sure your model has reasonable performance.
# 6. Implement the `attn` aggregation in `HeteroGNNWrapperConv`.
# 7. Train the model with `attn` aggregation across the message types and make sure your model has reasonable performance.

# %% [markdown]
# ## Setup

# %%
import copy
import torch
import deepsnap
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.nn as pyg_nn

from sklearn.metrics import f1_score
from deepsnap.hetero_gnn import forward_op
from deepsnap.hetero_graph import HeteroGraph
from torch_sparse import SparseTensor, matmul

# %% [markdown]
# ## Dataset
#
# You need to login to your Google account and enter the verification code below.

# %%
# 由于你在本地 VS Code 运行，而不是云端的 Google Colab，
# 所以不需要且无法使用 google.colab 和 PyDrive 进行认证。
# 我们直接安装 gdown，用于不用认证直接从 Google Drive 下载文件。
# !pip install -q gdown

# %%
# 使用 gdown 工具绕过 Google Colab 认证直接下载文件到本地目录
id = '1ivlxd6lJMcZ9taS44TMGG72x2V1GeVvk'
# !gdown --id {id} -O acm.pkl
# Out:
# D:\Anaconda\envs\Learn3.8\lib\site-packages\gdown\__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1ivlxd6lJMcZ9taS44TMGG72x2V1GeVvk
# From (redirected): https://drive.google.com/uc?id=1ivlxd6lJMcZ9taS44TMGG72x2V1GeVvk&confirm=t&uuid=9917dc41-bf5a-49c1-9760-89355d05eea5
# To: c:\Users\15pro\Desktop\cs224w\Colabs\acm.pkl
#
#   0%|          | 0.00/58.4M [00:00<?, ?B/s]
#   1%|          | 524k/58.4M [00:00<00:22, 2.57MB/s]
#   3%|▎         | 1.57M/58.4M [00:00<00:10, 5.36MB/s]
#   4%|▍         | 2.62M/58.4M [00:00<00:10, 5.23MB/s]
#  13%|█▎        | 7.86M/58.4M [00:00<00:02, 17.7MB/s]
#  18%|█▊        | 10.5M/58.4M [00:00<00:03, 14.7MB/s]
#  26%|██▌       | 15.2M/58.4M [00:00<00:01, 21.9MB/s]
#  32%|███▏      | 18.9M/58.4M [00:01<00:02, 19.4MB/s]
#  41%|████▏     | 24.1M/58.4M [00:01<00:01, 25.9MB/s]
#  48%|████▊     | 28.3M/58.4M [00:01<00:01, 21.8MB/s]
#  57%|█████▋    | 33.6M/58.4M [00:01<00:00, 27.4MB/s]
#  65%|██████▍   | 37.7M/58.4M [00:01<00:00, 30.3MB/s]
#  71%|███████   | 41.4M/58.4M [00:02<00:00, 23.2MB/s]
#  82%|████████▏ | 47.7M/58.4M [00:02<00:00, 30.6MB/s]
#  89%|████████▉ | 51.9M/58.4M [00:02<00:00, 30.8MB/s]
#  96%|█████████▌| 56.1M/58.4M [00:02<00:00, 33.2MB/s]
# 100%|██████████| 58.4M/58.4M [00:02<00:00, 24.1MB/s]

# %% [markdown]
# ## Heterogeneous GNN Layer
#
# Now let's start working on our own implementation of a heterogeneous layer (the `HeteroGNNConv`)! Similar to what we did in Colab 3, we will implement the layer using PyTorch Geometric. In general, our heterogeneous GNN layer draws ideas from the **GraphSAGE** ([Hamilton et al. (2017)](https://arxiv.org/abs/1706.02216)).
#
# At first, let's implement the GNN layer for each message type :
#
# \begin{equation}
# m =(s, r, d)
# \end{equation}
#
# Each message type is a tuple containing three elements where $s$ refers to the source node type, $r$ refers to the edge (relation) type and $d$ refers to the destination node type. The update rule is very similar to that of GraphSAGE but we need to include the node types and the edge type. The update rule is described as below:
#
# \begin{equation}
# h_v^{(l)[m]} = W^{(l)[m]} \cdot \text{CONCAT} \Big( W_d^{(l)[m]} \cdot h_v^{(l-1)}, W_s^{(l)[m]} \cdot AGG(\{h_u^{(l-1)}, \forall u \in N_{m}(v) \})\Big)
# \end{equation}
#
# where $[m]$ indicates that the weight matrices or embeddings with respect to message type $m$, $W_s^{(l)[m]}$ computes the messages from neighboring nodes, $W_d^{(l)[m]}$ compute messages from the node itself, and $W^{(l)[m]}$ aggregates messages from both node types. In the equation above, $v$ has the node type $d$, and $u$ has the node type $s$.
#
# For simplicity, we use mean aggregations for $AGG$ where:
#
# \begin{equation}
# AGG(\{h_u^{(l-1)}, \forall u \in N_{m}(v) \}) = \frac{1}{|N_{m}(v)|} \sum_{u\in N_{m}(v)} h_u^{(l-1)}
# \end{equation}

# %%
class HeteroGNNConv(pyg_nn.MessagePassing):
    def __init__(self, in_channels_src, in_channels_dst, out_channels):
        super(HeteroGNNConv, self).__init__(aggr="mean")

        self.in_channels_src = in_channels_src
        self.in_channels_dst = in_channels_dst
        self.out_channels = out_channels

        # To simplify implementation, please initialize both self.lin_dst
        # and self.lin_src out_features to out_channels
        self.lin_dst = None
        self.lin_src = None

        self.lin_update = None

        ############# Your code here #############
        ## (~3 lines of code)

        self.lin_dst = nn.Linear(in_channels_dst, out_channels)
        self.lin_src = nn.Linear(in_channels_src, out_channels)
        # 因为后续公式要求 CONCAT 操作，两部分的输出大小均为 out_channels
        # 拼接后的长度为 out_channels * 2
        self.lin_update = nn.Linear(out_channels * 2, out_channels)

        ##########################################

    def forward(
        self,
        node_feature_src,
        node_feature_dst,
        edge_index,
        size=None,
        res_n_id=None,
    ):
        ############# Your code here #############
        ## (~1 line of code)

        # PyG 的消息传递需要调用 propagate
        return self.propagate(edge_index, size=size, node_feature_src=node_feature_src, node_feature_dst=node_feature_dst, res_n_id=res_n_id)

        ##########################################

    def message_and_aggregate(self, edge_index, node_feature_src):

        ############# Your code here #############
        ## (~1 line of code)
        ## Note:
        ## 1. Different from what we implemented in Colab 3, we use message_and_aggregate
        ## to replace the message and aggregate. The benefit is that we can avoid
        ## materializing x_i and x_j, and make the implementation more efficient.
        ## 2. To implement efficiently, following PyG documentation is helpful:
        ## https://pytorch-geometric.readthedocs.io/en/latest/notes/sparse_tensor.html
        ## 3. Here edge_index is torch_sparse SparseTensor.

        out = matmul(edge_index, node_feature_src)
        
        ##########################################

        return out

    def update(self, aggr_out, node_feature_dst, res_n_id):

        ############# Your code here #############
        ## (~4 lines of code)

        # 计算并拼接 src 和 dst 端的特征
        dst_out = self.lin_dst(node_feature_dst)
        src_out = self.lin_src(aggr_out)
        
        # 沿着特征维度拼接 [batch_size, out_channels * 2]
        concat_out = torch.cat([dst_out, src_out], dim=-1)
        
        # 通过最后的全连接层
        aggr_out = self.lin_update(concat_out)

        ##########################################

        return aggr_out

# %% [markdown]
# ## Heterogeneous GNN Wrapper Layer
#
# After implementing the GNN layer for each message type, we need to somehow aggregate the the node embedding results (with respect to each message types) together. Here we will implement two types of message type level aggregation.
#
# The first one is simply the mean aggregation:
#
# \begin{equation}
# h_v^{(l)} = \frac{1}{M}\sum_{m=1}^{M}h_v^{(l)[m]}
# \end{equation}
#
# Here node $v$ has the node type $d$ and $M$ is the total number of message types that the destination node type is $d$.
#
# The other one is the semantic level attention introduced in **HAN** ([Wang et al. (2019)](https://arxiv.org/abs/1903.07293)). Instead of directly averaging on the message type aggregation results, we use attention to learn which message type result can be more important, then aggregate from all the message types. Following are the equations for semantic level attention:
#
# \begin{equation}
# e_{m} = \frac{1}{|V_{d}|} \sum_{v \in V_{d}} q_{attn}^T \cdot tanh \Big( W_{attn}^{(l)} \cdot h_v^{(l)[m]} + b \Big)
# \end{equation}
#
# where $m$ refers to message type and $d$ refers to the destination node type. Then we can compute the attention and update the $h_v^{(l)}$:
#
# \begin{equation}
# \alpha_{m} = \frac{\exp(e_{m})}{\sum_{m=1}^M \exp(e_{m})}
# \end{equation}
#
# \begin{equation}
# h_v^{(l)} = \sum_{m=1}^{M} \alpha_{m} \cdot h_v^{(l)[m]}
# \end{equation}
#
# 在为每种消息类型完成图神经网络层的实现后，我们需要对各类消息类型对应的节点嵌入结果进行聚合。本文将实现两种消息类型层级的聚合方式。
# 第一种为简单的均值聚合：
# \begin{equation}
# h_v^{(l)} = \frac{1}{M}\sum_{m=1}^{M}h_v^{(l)[m]}
# \end{equation}
# 其中节点
# v
#  的节点类型为
# d
# ，
# M
#  表示目标节点类型为
# d
#  的消息类型总数。
# 另一种是HAN 模型中提出的语义层级注意力机制（Wang 等人，2019）。该方式不再对不同消息类型的聚合结果直接取平均，而是通过注意力机制学习不同消息类型结果的重要程度，再完成多消息类型的特征聚合。语义层级注意力的计算公式如下：
# \begin{equation}
# e_{m} = \frac{1}{|V_{d}|} \sum_{v \in V_{d}} q_{attn}^T \cdot tanh \Big( W_{attn}^{(l)} \cdot h_v^{(l)[m]} + b \Big)
# \end{equation}
# 式中
# m
#  代表消息类型，
# d
#  代表目标节点类型。随后可计算注意力权重并更新节点特征
# h
# v
# (l)
# ​
#
# ：
# \begin{equation}
# \alpha_{m} = \frac{\exp(e_{m})}{\sum_{m=1}^M \exp(e_{m})}
# \end{equation}
# \begin{equation}
# h_v^{(l)} = \sum_{m=1}^{M} \alpha_{m} \cdot h_v^{(l)[m]}
# \end{equation}

# %%
class HeteroGNNWrapperConv(deepsnap.hetero_gnn.HeteroConv):
    def __init__(self, convs, args, aggr="mean"):
        super(HeteroGNNWrapperConv, self).__init__(convs, None)
        self.aggr = aggr

        # Map the index and message type
        self.mapping = {}

        # A numpy array that stores the final attention probability
        self.alpha = None

        self.attn_proj = None

        if self.aggr == "attn":
            ############# Your code here #############
            ## (~1 line of code)
            ## Note:
            ## 1. Initialize self.attn_proj here.
            ## 2. You should use nn.Sequential for self.attn_proj
            ## 3. nn.Linear and nn.Tanh are useful.
            ## 4. You can create a vector parameter by using:
            ## nn.Linear(some_size, 1, bias=False)
            ## 5. The first linear layer should have out_features as args['attn_size']
            ## 6. You can assume we only have one "head" for the attention.
            ## 7. We recommend you to implement the mean aggregation first. After
            ## the mean aggregation works well in the training, then you can
            ## implement this part.
            
            self.attn_proj = nn.Sequential(
                nn.Linear(args['hidden_size'], args['attn_size']),
                nn.Tanh(),
                nn.Linear(args['attn_size'], 1, bias=False)
            )


            ##########################################

    def reset_parameters(self):
        super(HeteroConvWrapper, self).reset_parameters()
        if self.aggr == "attn":
            for layer in self.attn_proj.children():
                layer.reset_parameters()

    def forward(self, node_features, edge_indices):
        message_type_emb = {}
        for message_key, message_type in edge_indices.items():
            src_type, edge_type, dst_type = message_key
            node_feature_src = node_features[src_type]
            node_feature_dst = node_features[dst_type]
            edge_index = edge_indices[message_key]
            message_type_emb[message_key] = (
                self.convs[message_key](
                    node_feature_src,
                    node_feature_dst,
                    edge_index,
                )
            )
        node_emb = {dst: [] for _, _, dst in message_type_emb.keys()}
        mapping = {}
        for (src, edge_type, dst), item in message_type_emb.items():
            mapping[len(node_emb[dst])] = (src, edge_type, dst)
            node_emb[dst].append(item)
        self.mapping = mapping
        for node_type, embs in node_emb.items():
            if len(embs) == 1:
                node_emb[node_type] = embs[0]
            else:
                node_emb[node_type] = self.aggregate(embs)
        return node_emb

    def aggregate(self, xs):
        # TODO: Implement this function that aggregates all message type results.
        # Here, xs is a list of tensors (embeddings) with respect to message
        # type aggregation results.
        
        out = None

        if self.aggr == "mean":

            ############# Your code here #############
            ## (~2 lines of code)

            # 直接对所有 message type 的结果取平均
            
            out = torch.mean(torch.stack(xs, dim=0), dim=0)

            ##########################################
            return out

        elif self.aggr == "attn":

            ############# Your code here #############
            ## (~10 lines of code)
            ## Note:
            ## 1. Store the value of attention alpha (as a numpy array) to self.alpha,
            ## which has the shape (len(xs), ) self.alpha will be not be used
            ## to backpropagate etc. in the model. We will use it to see how much
            ## attention the layer pays on different message types.
            ## 2. torch.softmax and torch.cat are useful.
            ## 3. You might need to reshape the tensors by using the
            ## `view()` function https://pytorch.org/docs/stable/tensor_view.html

            # 将 M 个特征维度为 [N, hidden] 的张量堆叠 -> [M, N, hidden]
            x_stacked = torch.stack(xs, dim=0)
            
            # 使用 self.attn_proj 输出打分，得到 [M, N, 1] 
            e = self.attn_proj(x_stacked).squeeze(-1) # [M, N]
            
            # 按照公式对 N（即每个目标节点）求均值得到每个消息类型的得分 [M]
            e = torch.mean(e, dim=1)
            
            # 沿消息类型维度(M)做 Softmax 归一化
            alpha = torch.softmax(e, dim=0)
            
            # 存入到 self.alpha 中，保存为 numpy 数组方便后续可解释性展示
            self.alpha = alpha.detach().cpu().numpy()
            
            # α 的形状扩充成 [M, 1, 1] 随后与 [M, N, hidden] 相乘并在 M 的维度求和
            out = torch.sum(x_stacked * alpha.view(-1, 1, 1), dim=0)

            ##########################################
            
            return out

# %% [markdown]
# ## Initialize Heterogeneous GNN Layers
#
# Now let's initialize the Heterogeneous GNN Layers. Different from homogeneous graph case, heterogeneous case can be a little bit complex.
#
# In general, we need to create a dictionary of `HeteroGNNConv` layers where the keys are message types.
#
# * To get all message types, `deepsnap.hetero_graph.HeteroGraph.message_types` is useful.
# * If we are initializing the first conv layers, we need to get the feature dimension of each node type. Using `deepsnap.hetero_graph.HeteroGraph.num_node_features(node_type)` will return the node feature dimension of `node_type`. In this function, we will set each `HeteroGNNConv` `out_channels` to be `hidden_size`.
# * If we are not initializing the first conv layers, all node types will have the same embedding dimension `hidden_size` and we still set `HeteroGNNConv` `out_channels` to be `hidden_size` for simplicity.
#
#
# ## 初始化异构图神经网络层
# 接下来我们初始化异构图神经网络（GNN）层。与同构图场景不同，异构图场景的实现会相对复杂一些。
#
# 通常情况下，我们需要创建一个由`HeteroGNNConv`层组成的字典，字典的键为消息类型。
#
# - 如需获取全部消息类型，可使用`deepsnap.hetero_graph.HeteroGraph.message_types`方法。
# - 若初始化的是首层卷积层，需要获取每种节点类型的特征维度。通过`deepsnap.hetero_graph.HeteroGraph.num_node_features(node_type)`可以返回指定节点类型的特征维度。在该方法中，我们将每个`HeteroGNNConv`的输出通道数`out_channels`统一设置为`hidden_size`。
# - 若并非初始化首层卷积层，所有节点类型都会拥有相同的嵌入维度`hidden_size`；为简化实现，我们依旧将`HeteroGNNConv`的`out_channels`设为`hidden_size`。
#
# ---
# ### 专有名词解释
# | 英文术语 | 中文释义 |
# | :--- | :--- |
# | Heterogeneous GNN | 异构图神经网络 |
# | Homogeneous graph | 同构图 |
# | Heterogeneous graph | 异构图 |
# | message types | 消息类型 |
# | feature dimension | 特征维度 |
# | embedding dimension | 嵌入维度 |
# | out_channels | 输出通道数 |
# | hidden_size | 隐藏层维度 |

# %%
def generate_convs(hetero_graph, conv, hidden_size, first_layer=False):
    # TODO: Implement this function that returns a dictionary of `HeteroGNNConv`
    # layers where the keys are message types. `hetero_graph` is deepsnap `HeteroGraph`
    # object and the `conv` is the `HeteroGNNConv`.

    convs = {}

    ############# Your code here #############
    ## (~9 lines of code)
    
    # 遍历 DeepSNAP 图结构中所有的消息类型
    # message_type 是一组三元组，比如 ('paper', 'author', 'paper')
    for message_type in hetero_graph.message_types:
        # 如果是图神经网络的第一层，我们需要利用原始不同节点的特征维度
        if first_layer:
            # message_type 的索引 0 是 source，2 是 destination
            in_channels_src = hetero_graph.num_node_features(message_type[0])
            in_channels_dst = hetero_graph.num_node_features(message_type[2])
        else:
            # 如果不是第一层，由于经过了前面的映射，所有节点的隐藏维度都变成了 hidden_size
            in_channels_src = hidden_size
            in_channels_dst = hidden_size
        
        # 实例化 `HeteroGNNConv` 并使用 message_type 作为字典的 key 保存起来
        # out_channels 固定为 hidden_size
        convs[message_type] = conv(in_channels_src, in_channels_dst, out_channels=hidden_size)

    ##########################################

    return convs

# %% [markdown]
# ## HeteroGNN
#
# Now we will make a simple HeteroGNN model which contains only two `HeteroGNNWrapperConv` layers.
#
# For the forward function in `HeteroGNN`, the model is going to be run as following:
#
# $\text{self.convs1} \rightarrow \text{self.bns1} \rightarrow \text{self.relus1} \rightarrow \text{self.convs2} \rightarrow \text{self.bns2} \rightarrow \text{self.relus2} \rightarrow \text{self.post_mps}$

# %%
class HeteroGNN(torch.nn.Module):
    def __init__(self, hetero_graph, args, aggr="mean"):
        super(HeteroGNN, self).__init__()

        self.aggr = aggr
        self.hidden_size = args['hidden_size']

        self.convs1 = None
        self.convs2 = None

        self.bns1 = nn.ModuleDict()
        self.bns2 = nn.ModuleDict()
        self.relus1 = nn.ModuleDict()
        self.relus2 = nn.ModuleDict()
        self.post_mps = nn.ModuleDict()

        ############# Your code here #############
        ## (~10 lines of code)
        ## Note:
        ## 1. For self.convs1 and self.convs2, call generate_convs at first and then
        ## pass the returned dictionary of `HeteroGNNConv` to `HeteroGNNWrapperConv`.
        ## 2. For self.bns, self.relus and self.post_mps, the keys are node_types.
        ## `deepsnap.hetero_graph.HeteroGraph.node_types` will be helpful.
        ## 3. Initialize all batchnorms to torch.nn.BatchNorm1d(hidden_size, eps=1.0).
        ## 4. Initialize all relus to nn.LeakyReLU().
        ## 5. For self.post_mps, each value in the ModuleDict is a linear layer
        ## where the `out_features` is the number of classes for that node type.
        ## `deepsnap.hetero_graph.HeteroGraph.num_node_labels(node_type)` will be
        ## useful.
        
        # 第一层卷积：从原始节点特征映射到 hidden_size，并且 first_layer=True
        conv1_dict = generate_convs(hetero_graph, HeteroGNNConv, self.hidden_size, first_layer=True)
        self.convs1 = HeteroGNNWrapperConv(convs=conv1_dict, args=args, aggr=self.aggr)
        
        # 第二层卷积：图的隐含层之间的消息传递，first_layer=False
        conv2_dict = generate_convs(hetero_graph, HeteroGNNConv, self.hidden_size, first_layer=False)
        self.convs2 = HeteroGNNWrapperConv(convs=conv2_dict, args=args, aggr=self.aggr)
        
        # 根据 node_types 构建对应的 BatchNorm、ReLU 以及最后的预测全连接层
        for node_type in hetero_graph.node_types:
            self.bns1[node_type] = nn.BatchNorm1d(self.hidden_size, eps=1.0)
            self.bns2[node_type] = nn.BatchNorm1d(self.hidden_size, eps=1.0)
            self.relus1[node_type] = nn.LeakyReLU()
            self.relus2[node_type] = nn.LeakyReLU()
            self.post_mps[node_type] = nn.Linear(self.hidden_size, hetero_graph.num_node_labels(node_type))


        ##########################################

    def forward(self, node_feature, edge_index):
        # TODO: Implement the forward function. Notice that `node_feature` is
        # a dictionary of tensors where keys are node types and values are
        # corresponding feature tensors. The `edge_index` is a dictionary of
        # tensors where keys are message types and values are corresponding
        # edge index tensors (with respect to each message type).

        x = node_feature

        ############# Your code here #############
        ## (~7 lines of code)
        ## Note:
        ## 1. `deepsnap.hetero_gnn.forward_op` can be helpful.

        # 这里不应该使用 deepsnap.hetero_gnn.forward_op，
        # 因为我们使用的 HeteroGNNWrapperConv 能够直接处理包含所有 node/edge dict 的输入
        # 这里正确用法是直接调用 wrapper 并依次对 node dict 更新
        
        # 1. 经过第一层 wrapper 得到新的 node_emb dict
        x = self.convs1(x, edge_index)
        x = forward_op(x, self.bns1)
        x = forward_op(x, self.relus1)
        
        # 2. 经过第二层 wrapper 得到新的 node_emb dict
        x = self.convs2(x, edge_index)
        x = forward_op(x, self.bns2)
        x = forward_op(x, self.relus2)
        
        # 3. 经过输出层得到类别预测值
        x = forward_op(x, self.post_mps)

        ##########################################

        return x

    def loss(self, preds, y, indices):

        loss = 0
        loss_func = F.cross_entropy

        ############# Your code here #############
        ## (~3 lines of code)
        ## Note:
        ## 1. For each node type in preds, accumulate computed loss to `loss`
        ## 2. Loss need to be computed with respect to the given index
        
        for node_type in preds:
            # 仅取出掩码 mask / indices 中有的节点计算交叉熵损失
            idx = indices[node_type]
            loss += loss_func(preds[node_type][idx], y[node_type][idx])


        ##########################################

        return loss

# %% [markdown]
# ## Training and Testing
#
# Here we provide you with the functions to train and test. You only need to implement one line of code here.
#
# **Please do not modify other parts in `train` and `test` for grading purposes.**

# %%
def train(model, optimizer, hetero_graph, train_idx):
    model.train()
    optimizer.zero_grad()
    preds = model(hetero_graph.node_feature, hetero_graph.edge_index)

    loss = None

    ############# Your code here #############
    ## Note:
    ## 1. `deepsnap.hetero_graph.HeteroGraph.node_label` is useful
    ## 2. Compute the loss here
    
    loss = model.loss(preds, hetero_graph.node_label, train_idx)
    


    ##########################################

    loss.backward()
    optimizer.step()
    return loss.item()

def test(model, graph, indices, best_model=None, best_val=0):
    model.eval()
    accs = []
    for index in indices:
        preds = model(graph.node_feature, graph.edge_index)
        num_node_types = 0
        micro = 0
        macro = 0
        for node_type in preds:
            idx = index[node_type]
            pred = preds[node_type][idx]
            pred = pred.max(1)[1]
            label_np = graph.node_label[node_type][idx].cpu().numpy()
            pred_np = pred.cpu().numpy()
            micro = f1_score(label_np, pred_np, average='micro')
            macro = f1_score(label_np, pred_np, average='macro')
            num_node_types += 1
        # Averaging f1 score might not make sense, but in our example we only
        # have one node type
        micro /= num_node_types
        macro /= num_node_types
        accs.append((micro, macro))
    if accs[1][0] > best_val:
        best_val = accs[1][0]
        best_model = copy.deepcopy(model)
    return accs, best_model, best_val

# %%
# Please do not change the following parameters
args = {
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'hidden_size': 64,
    'epochs': 100,
    'weight_decay': 1e-5,
    'lr': 0.003,
    'attn_size': 32,
}

# %% [markdown]
# ## Dataset and Preprocessing
#
# In the next, we will load the data and create a tensor backend (without a NetworkX graph) `deepsnap.hetero_graph.HeteroGraph` object.
#
# We will use the `ACM(3025)` dataset in our node property prediction task, which is proposed in **HAN** ([Wang et al. (2019)](https://arxiv.org/abs/1903.07293)) and our dataset is extracted from [DGL](https://www.dgl.ai/)'s [ACM.mat](https://data.dgl.ai/dataset/ACM.mat).
#
# The original ACM dataset has three node types and two edge (relation) types. For simplicity, we simplify the heterogeneous graph to one node type and two edge types (shown below). This means that in our heterogeneous graph, we have one node type (paper) and two message types (paper, author, paper) and (paper, subject, paper).
#
# <br/>
# <center>
# <img src="http://web.stanford.edu/class/cs224w/images/colab4/cs224w-acm.png"/>
# </center>

# %%
print("Device: {}".format(args['device']))

# Load the data
data = torch.load("acm.pkl")

# Message types
message_type_1 = ("paper", "author", "paper")
message_type_2 = ("paper", "subject", "paper")

# Dictionary of edge indices
edge_index = {}
edge_index[message_type_1] = data['pap']
edge_index[message_type_2] = data['psp']

# Dictionary of node features
node_feature = {}
node_feature["paper"] = data['feature']

# Dictionary of node labels
node_label = {}
node_label["paper"] = data['label']

# Load the train, validation and test indices
train_idx = {"paper": data['train_idx'].to(args['device'])}
val_idx = {"paper": data['val_idx'].to(args['device'])}
test_idx = {"paper": data['test_idx'].to(args['device'])}

# Construct a deepsnap tensor backend HeteroGraph
hetero_graph = HeteroGraph(
    node_feature=node_feature,
    node_label=node_label,
    edge_index=edge_index,
    directed=True
)

print(f"ACM heterogeneous graph: {hetero_graph.num_nodes()} nodes, {hetero_graph.num_edges()} edges")

# Node feature and node label to device
for key in hetero_graph.node_feature:
    hetero_graph.node_feature[key] = hetero_graph.node_feature[key].to(args['device'])
for key in hetero_graph.node_label:
    hetero_graph.node_label[key] = hetero_graph.node_label[key].to(args['device'])

# Edge_index to sparse tensor and to device
for key in hetero_graph.edge_index:
    edge_index = hetero_graph.edge_index[key]
    adj = SparseTensor(row=edge_index[0], col=edge_index[1], sparse_sizes=(hetero_graph.num_nodes('paper'), hetero_graph.num_nodes('paper')))
    hetero_graph.edge_index[key] = adj.t().to(args['device'])
print(hetero_graph.edge_index[message_type_1])
print(hetero_graph.edge_index[message_type_2])
# Out:
# Device: cuda
# ACM heterogeneous graph: {'paper': 3025} nodes, {('paper', 'author', 'paper'): 26256, ('paper', 'subject', 'paper'): 2207736} edges
# C:\Users\15pro\AppData\Local\Temp\ipykernel_10216\1058933188.py:4: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   data = torch.load("acm.pkl")
# SparseTensor(row=tensor([   0,    0,    0,  ..., 3024, 3024, 3024], device='cuda:0'),
#              col=tensor([   8,   20,   51,  ..., 2948, 2983, 2991], device='cuda:0'),
#              size=(3025, 3025), nnz=26256, density=0.29%)
# SparseTensor(row=tensor([   0,    0,    0,  ..., 3024, 3024, 3024], device='cuda:0'),
#              col=tensor([  75,  434,  534,  ..., 3020, 3021, 3022], device='cuda:0'),
#              size=(3025, 3025), nnz=2207736, density=24.13%)

# %% [markdown]
# ## Start Training!
#
# Now lets start training!

# %% [markdown]
# ## Training the Mean Aggregation

# %%
best_model = None
best_val = 0

model = HeteroGNN(hetero_graph, args, aggr="mean").to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

for epoch in range(args['epochs']):
    loss = train(model, optimizer, hetero_graph, train_idx)
    accs, best_model, best_val = test(model, hetero_graph, [train_idx, val_idx, test_idx], best_model, best_val)
    print(
        f"Epoch {epoch + 1}: loss {round(loss, 5)}, "
        f"train micro {round(accs[0][0] * 100, 2)}%, train macro {round(accs[0][1] * 100, 2)}%, "
        f"valid micro {round(accs[1][0] * 100, 2)}%, valid macro {round(accs[1][1] * 100, 2)}%, "
        f"test micro {round(accs[2][0] * 100, 2)}%, test macro {round(accs[2][1] * 100, 2)}%"
    )
best_accs, _, _ = test(best_model, hetero_graph, [train_idx, val_idx, test_idx])
print(
    f"Best model: "
    f"train micro {round(best_accs[0][0] * 100, 2)}%, train macro {round(best_accs[0][1] * 100, 2)}%, "
    f"valid micro {round(best_accs[1][0] * 100, 2)}%, valid macro {round(best_accs[1][1] * 100, 2)}%, "
    f"test micro {round(best_accs[2][0] * 100, 2)}%, test macro {round(best_accs[2][1] * 100, 2)}%"
)
# Out:
# Epoch 1: loss 1.10449, train micro 31.33%, train macro 20.81%, valid micro 33.33%, valid macro 21.78%, test micro 33.41%, test macro 22.28%
# Epoch 2: loss 1.04214, train micro 61.5%, train macro 56.25%, valid micro 58.33%, valid macro 50.1%, test micro 58.12%, test macro 51.38%
# Epoch 3: loss 0.85839, train micro 62.0%, train macro 61.77%, valid micro 53.33%, valid macro 49.25%, test micro 53.04%, test macro 51.97%
# Epoch 4: loss 0.744, train micro 62.0%, train macro 62.26%, valid micro 53.0%, valid macro 49.82%, test micro 53.13%, test macro 53.53%
# Epoch 5: loss 0.68523, train micro 61.67%, train macro 62.04%, valid micro 53.33%, valid macro 49.71%, test micro 50.73%, test macro 50.6%
# Epoch 6: loss 0.65369, train micro 68.5%, train macro 65.98%, valid micro 61.67%, valid macro 52.75%, test micro 58.73%, test macro 52.93%
# Epoch 7: loss 0.63919, train micro 64.83%, train macro 63.29%, valid micro 59.0%, valid macro 53.57%, test micro 61.27%, test macro 60.07%
# Epoch 8: loss 0.62519, train micro 63.17%, train macro 60.26%, valid micro 60.0%, valid macro 54.1%, test micro 62.21%, test macro 60.63%
# Epoch 9: loss 0.61596, train micro 62.17%, train macro 58.13%, valid micro 60.33%, valid macro 54.29%, test micro 61.79%, test macro 59.59%
# Epoch 10: loss 0.60652, train micro 64.5%, train macro 57.71%, valid micro 63.0%, valid macro 53.25%, test micro 59.72%, test macro 50.82%
# Epoch 11: loss 0.59923, train micro 64.5%, train macro 57.71%, valid micro 63.0%, valid macro 53.25%, test micro 59.67%, test macro 50.72%
# Epoch 12: loss 0.59372, train micro 64.5%, train macro 57.71%, valid micro 63.0%, valid macro 53.25%, test micro 59.62%, test macro 50.7%
# Epoch 13: loss 0.58825, train micro 64.5%, train macro 58.13%, valid micro 63.0%, valid macro 53.25%, test micro 59.62%, test macro 50.87%
# Epoch 14: loss 0.58315, train micro 64.67%, train macro 58.43%, valid micro 63.0%, valid macro 53.25%, test micro 59.62%, test macro 50.98%
# Epoch 15: loss 0.57825, train micro 64.83%, train macro 58.94%, valid micro 63.0%, valid macro 53.25%, test micro 59.53%, test macro 51.02%
# Epoch 16: loss 0.57221, train micro 65.67%, train macro 60.41%, valid micro 63.0%, valid macro 53.25%, test micro 59.29%, test macro 51.04%
# Epoch 17: loss 0.56956, train micro 66.17%, train macro 61.26%, valid micro 63.0%, valid macro 53.25%, test micro 59.25%, test macro 51.28%
# Epoch 18: loss 0.56624, train micro 66.33%, train macro 61.87%, valid micro 63.0%, valid macro 53.25%, test micro 59.11%, test macro 51.52%
# Epoch 19: loss 0.56374, train micro 67.0%, train macro 63.38%, valid micro 62.67%, valid macro 53.16%, test micro 59.06%, test macro 51.71%
# Epoch 20: loss 0.56068, train micro 67.33%, train macro 64.02%, valid micro 62.67%, valid macro 53.16%, test micro 58.96%, test macro 51.92%
# Epoch 21: loss 0.55843, train micro 67.17%, train macro 63.9%, valid micro 62.67%, valid macro 53.16%, test micro 58.92%, test macro 51.98%
# Epoch 22: loss 0.55591, train micro 67.5%, train macro 64.4%, valid micro 62.67%, valid macro 53.16%, test micro 59.06%, test macro 52.32%
# Epoch 23: loss 0.55448, train micro 70.67%, train macro 70.16%, valid micro 72.33%, valid macro 70.79%, test micro 58.35%, test macro 56.12%
# Epoch 24: loss 0.5512, train micro 74.5%, train macro 75.01%, valid micro 74.33%, valid macro 74.82%, test micro 61.46%, test macro 63.13%
# Epoch 25: loss 0.54903, train micro 73.33%, train macro 73.79%, valid micro 73.67%, valid macro 74.13%, test micro 61.46%, test macro 63.24%
# Epoch 26: loss 0.54931, train micro 72.83%, train macro 73.29%, valid micro 74.0%, valid macro 74.16%, test micro 60.19%, test macro 60.82%
# Epoch 27: loss 0.54434, train micro 68.33%, train macro 65.52%, valid micro 62.67%, valid macro 53.22%, test micro 58.82%, test macro 52.34%
# Epoch 28: loss 0.54367, train micro 68.5%, train macro 65.75%, valid micro 62.67%, valid macro 53.22%, test micro 59.01%, test macro 52.81%
# Epoch 29: loss 0.53962, train micro 68.5%, train macro 65.87%, valid micro 62.67%, valid macro 53.22%, test micro 59.06%, test macro 53.02%
# Epoch 30: loss 0.53782, train micro 72.33%, train macro 72.6%, valid micro 73.0%, valid macro 72.69%, test micro 59.39%, test macro 59.14%
# Epoch 31: loss 0.53603, train micro 72.67%, train macro 72.97%, valid micro 72.33%, valid macro 72.18%, test micro 59.53%, test macro 59.72%
# Epoch 32: loss 0.53464, train micro 71.33%, train macro 71.3%, valid micro 70.0%, valid macro 69.22%, test micro 58.45%, test macro 57.32%
# Epoch 33: loss 0.53278, train micro 71.33%, train macro 71.21%, valid micro 70.0%, valid macro 68.93%, test micro 58.4%, test macro 57.04%
# Epoch 34: loss 0.53091, train micro 71.83%, train macro 72.37%, valid micro 72.33%, valid macro 72.39%, test micro 59.72%, test macro 60.53%
# Epoch 35: loss 0.52826, train micro 75.5%, train macro 75.92%, valid micro 74.67%, valid macro 75.13%, test micro 61.79%, test macro 63.46%
# Epoch 36: loss 0.52643, train micro 74.67%, train macro 75.04%, valid micro 74.67%, valid macro 75.13%, test micro 61.65%, test macro 63.36%
# Epoch 37: loss 0.52431, train micro 74.0%, train macro 74.57%, valid micro 74.33%, valid macro 74.79%, test micro 61.18%, test macro 62.65%
# Epoch 38: loss 0.52153, train micro 70.17%, train macro 70.75%, valid micro 71.33%, valid macro 71.33%, test micro 59.11%, test macro 60.02%
# Epoch 39: loss 0.519, train micro 71.17%, train macro 71.61%, valid micro 71.33%, valid macro 71.25%, test micro 60.14%, test macro 60.61%
# Epoch 40: loss 0.51616, train micro 71.83%, train macro 72.45%, valid micro 72.33%, valid macro 72.65%, test micro 59.91%, test macro 61.09%
# Epoch 41: loss 0.51377, train micro 75.0%, train macro 75.28%, valid micro 74.67%, valid macro 75.08%, test micro 61.46%, test macro 63.31%
# Epoch 42: loss 0.51138, train micro 75.5%, train macro 75.6%, valid micro 74.0%, valid macro 74.31%, test micro 62.26%, test macro 64.02%
# Epoch 43: loss 0.50905, train micro 75.83%, train macro 76.01%, valid micro 73.67%, valid macro 74.04%, test micro 62.02%, test macro 63.82%
# Epoch 44: loss 0.5051, train micro 75.33%, train macro 75.58%, valid micro 74.67%, valid macro 75.07%, test micro 61.27%, test macro 63.13%
# Epoch 45: loss 0.50326, train micro 75.5%, train macro 75.5%, valid micro 75.33%, valid macro 75.39%, test micro 62.92%, test macro 64.56%
# Epoch 46: loss 0.49999, train micro 75.17%, train macro 75.16%, valid micro 75.0%, valid macro 75.14%, test micro 62.92%, test macro 64.56%
# Epoch 47: loss 0.49932, train micro 75.83%, train macro 75.8%, valid micro 74.33%, valid macro 74.59%, test micro 62.54%, test macro 64.24%
# Epoch 48: loss 0.49654, train micro 75.83%, train macro 76.0%, valid micro 74.67%, valid macro 74.98%, test micro 62.16%, test macro 63.94%
# Epoch 49: loss 0.49346, train micro 76.17%, train macro 76.22%, valid micro 74.33%, valid macro 74.63%, test micro 62.4%, test macro 64.13%
# Epoch 50: loss 0.49179, train micro 74.83%, train macro 74.49%, valid micro 75.67%, valid macro 75.44%, test micro 62.96%, test macro 64.33%
# Epoch 51: loss 0.48891, train micro 75.5%, train macro 75.19%, valid micro 76.33%, valid macro 76.04%, test micro 63.11%, test macro 64.46%
# Epoch 52: loss 0.48653, train micro 76.0%, train macro 75.81%, valid micro 77.0%, valid macro 76.85%, test micro 63.11%, test macro 64.6%
# Epoch 53: loss 0.48381, train micro 76.0%, train macro 75.77%, valid micro 77.0%, valid macro 76.85%, test micro 63.48%, test macro 64.95%
# Epoch 54: loss 0.48073, train micro 76.0%, train macro 75.68%, valid micro 77.0%, valid macro 76.78%, test micro 63.81%, test macro 65.19%
# Epoch 55: loss 0.4794, train micro 77.5%, train macro 77.56%, valid micro 77.33%, valid macro 77.56%, test micro 63.29%, test macro 64.98%
# Epoch 56: loss 0.47644, train micro 74.33%, train macro 74.83%, valid micro 76.33%, valid macro 76.63%, test micro 62.12%, test macro 63.55%
# Epoch 57: loss 0.47444, train micro 70.5%, train macro 68.88%, valid micro 64.0%, valid macro 55.99%, test micro 60.05%, test macro 56.32%
# Epoch 58: loss 0.49615, train micro 74.17%, train macro 73.0%, valid micro 79.0%, valid macro 78.11%, test micro 64.28%, test macro 65.05%
# Epoch 59: loss 0.5099, train micro 73.67%, train macro 72.48%, valid micro 79.33%, valid macro 78.35%, test micro 63.91%, test macro 64.73%
# Epoch 60: loss 0.50639, train micro 75.33%, train macro 74.75%, valid micro 79.67%, valid macro 78.92%, test micro 64.94%, test macro 66.19%
# Epoch 61: loss 0.48995, train micro 74.83%, train macro 74.43%, valid micro 79.33%, valid macro 78.7%, test micro 64.66%, test macro 66.02%
# Epoch 62: loss 0.49107, train micro 75.5%, train macro 75.21%, valid micro 79.0%, valid macro 78.4%, test micro 64.56%, test macro 66.0%
# Epoch 63: loss 0.49327, train micro 75.5%, train macro 75.21%, valid micro 78.33%, valid macro 77.79%, test micro 64.14%, test macro 65.62%
# Epoch 64: loss 0.48981, train micro 76.0%, train macro 75.71%, valid micro 78.0%, valid macro 77.49%, test micro 64.0%, test macro 65.49%
# Epoch 65: loss 0.48466, train micro 76.0%, train macro 75.68%, valid micro 78.67%, valid macro 78.09%, test micro 64.05%, test macro 65.5%
# Epoch 66: loss 0.48072, train micro 76.33%, train macro 75.97%, valid micro 79.0%, valid macro 78.48%, test micro 64.24%, test macro 65.66%
# Epoch 67: loss 0.47848, train micro 76.5%, train macro 76.17%, valid micro 78.67%, valid macro 78.17%, test micro 64.71%, test macro 66.12%
# Epoch 68: loss 0.4759, train micro 76.67%, train macro 76.36%, valid micro 79.0%, valid macro 78.55%, test micro 64.38%, test macro 65.85%
# Epoch 69: loss 0.4734, train micro 77.0%, train macro 76.77%, valid micro 79.0%, valid macro 78.55%, test micro 64.71%, test macro 66.2%
# Epoch 70: loss 0.46786, train micro 77.83%, train macro 77.74%, valid micro 79.67%, valid macro 79.43%, test micro 64.94%, test macro 66.48%
# Epoch 71: loss 0.46156, train micro 77.83%, train macro 77.82%, valid micro 79.0%, valid macro 78.91%, test micro 65.04%, test macro 66.59%
# Epoch 72: loss 0.45854, train micro 78.5%, train macro 78.49%, valid micro 79.67%, valid macro 79.62%, test micro 64.94%, test macro 66.52%
# Epoch 73: loss 0.45563, train micro 78.5%, train macro 78.47%, valid micro 79.67%, valid macro 79.58%, test micro 65.04%, test macro 66.57%
# Epoch 74: loss 0.45224, train micro 78.5%, train macro 78.44%, valid micro 80.67%, valid macro 80.47%, test micro 65.27%, test macro 66.77%
# Epoch 75: loss 0.44738, train micro 78.33%, train macro 78.28%, valid micro 80.67%, valid macro 80.47%, test micro 65.46%, test macro 66.95%
# Epoch 76: loss 0.44297, train micro 79.17%, train macro 79.23%, valid micro 81.67%, valid macro 81.55%, test micro 65.88%, test macro 67.37%
# Epoch 77: loss 0.43773, train micro 77.33%, train macro 77.65%, valid micro 82.0%, valid macro 82.13%, test micro 65.88%, test macro 67.06%
# Epoch 78: loss 0.44299, train micro 78.5%, train macro 78.73%, valid micro 82.33%, valid macro 82.45%, test micro 66.35%, test macro 67.62%
# Epoch 79: loss 0.43359, train micro 80.17%, train macro 80.15%, valid micro 82.67%, valid macro 82.62%, test micro 66.31%, test macro 67.76%
# Epoch 80: loss 0.42839, train micro 79.67%, train macro 79.69%, valid micro 81.67%, valid macro 81.63%, test micro 66.35%, test macro 67.78%
# Epoch 81: loss 0.42443, train micro 80.0%, train macro 80.15%, valid micro 84.67%, valid macro 84.7%, test micro 67.72%, test macro 69.0%
# Epoch 82: loss 0.42008, train micro 80.83%, train macro 81.01%, valid micro 84.67%, valid macro 84.72%, test micro 68.19%, test macro 69.38%
# Epoch 83: loss 0.41887, train micro 79.83%, train macro 80.1%, valid micro 83.67%, valid macro 83.8%, test micro 67.67%, test macro 68.54%
# Epoch 84: loss 0.40745, train micro 79.83%, train macro 80.06%, valid micro 82.67%, valid macro 82.81%, test micro 67.06%, test macro 67.74%
# Epoch 85: loss 0.40244, train micro 77.0%, train macro 77.01%, valid micro 79.67%, valid macro 79.64%, test micro 64.28%, test macro 64.28%
# Epoch 86: loss 0.39486, train micro 72.5%, train macro 70.38%, valid micro 67.33%, valid macro 60.51%, test micro 62.78%, test macro 58.12%
# Epoch 87: loss 0.40536, train micro 72.67%, train macro 70.52%, valid micro 67.33%, valid macro 60.91%, test micro 62.64%, test macro 57.97%
# Epoch 88: loss 0.38429, train micro 77.67%, train macro 77.43%, valid micro 81.33%, valid macro 81.04%, test micro 65.04%, test macro 64.3%
# Epoch 89: loss 0.37995, train micro 70.83%, train macro 67.52%, valid micro 64.67%, valid macro 55.33%, test micro 60.99%, test macro 54.41%
# Epoch 90: loss 0.38285, train micro 70.5%, train macro 67.13%, valid micro 64.67%, valid macro 55.33%, test micro 60.94%, test macro 54.33%
# Epoch 91: loss 0.36467, train micro 70.67%, train macro 67.26%, valid micro 64.67%, valid macro 55.33%, test micro 61.08%, test macro 54.56%
# Epoch 92: loss 0.35793, train micro 70.5%, train macro 66.89%, valid micro 65.0%, valid macro 55.49%, test micro 61.08%, test macro 54.3%
# Epoch 93: loss 0.34505, train micro 69.83%, train macro 65.85%, valid micro 65.67%, valid macro 55.84%, test micro 60.71%, test macro 53.47%
# Epoch 94: loss 0.33429, train micro 70.0%, train macro 66.23%, valid micro 65.67%, valid macro 55.84%, test micro 60.85%, test macro 53.79%
# Epoch 95: loss 0.3224, train micro 70.17%, train macro 66.49%, valid micro 65.33%, valid macro 55.68%, test micro 60.99%, test macro 54.01%
# Epoch 96: loss 0.30855, train micro 70.33%, train macro 66.62%, valid micro 65.33%, valid macro 55.62%, test micro 60.8%, test macro 53.61%
# Epoch 97: loss 0.29567, train micro 69.83%, train macro 65.84%, valid micro 65.33%, valid macro 55.62%, test micro 60.47%, test macro 53.14%
# Epoch 98: loss 0.28051, train micro 70.5%, train macro 66.87%, valid micro 65.33%, valid macro 55.68%, test micro 60.71%, test macro 53.67%
# Epoch 99: loss 0.27178, train micro 88.5%, train macro 88.59%, valid micro 89.0%, valid macro 89.04%, test micro 71.2%, test macro 71.22%
# Epoch 100: loss 0.33276, train micro 74.33%, train macro 72.58%, valid micro 70.0%, valid macro 64.11%, test micro 63.81%, test macro 58.73%
# Best model: train micro 88.5%, train macro 88.59%, valid micro 89.0%, valid macro 89.04%, test micro 71.2%, test macro 71.22%

# %% [markdown]
# ## Question 2.1: What is the maximum **micro** F1 score you could get for the best_model on test set when using the mean aggregation? (10 points)
#
# Submit your answers on Gradescope.

# %% [markdown]
# ## Question 2.2: What is the maximum **macro** F1 score you could get for the best_model on test set when using the mean aggregation? (10 points)
#
# Submit your answers on Gradescope.

# %% [markdown]
# ## Training the Attention Aggregation

# %%
best_model = None
best_val = 0

output_size = hetero_graph.num_node_labels('paper')
model = HeteroGNN(hetero_graph, args, aggr="attn").to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

for epoch in range(args['epochs']):
    loss = train(model, optimizer, hetero_graph, train_idx)
    accs, best_model, best_val = test(model, hetero_graph, [train_idx, val_idx, test_idx], best_model, best_val)
    print(
        f"Epoch {epoch + 1}: loss {round(loss, 5)}, "
        f"train micro {round(accs[0][0] * 100, 2)}%, train macro {round(accs[0][1] * 100, 2)}%, "
        f"valid micro {round(accs[1][0] * 100, 2)}%, valid macro {round(accs[1][1] * 100, 2)}%, "
        f"test micro {round(accs[2][0] * 100, 2)}%, test macro {round(accs[2][1] * 100, 2)}%"
    )
best_accs, _, _ = test(best_model, hetero_graph, [train_idx, val_idx, test_idx])
print(
    f"Best model: "
    f"train micro {round(best_accs[0][0] * 100, 2)}%, train macro {round(best_accs[0][1] * 100, 2)}%, "
    f"valid micro {round(best_accs[1][0] * 100, 2)}%, valid macro {round(best_accs[1][1] * 100, 2)}%, "
    f"test micro {round(best_accs[2][0] * 100, 2)}%, test macro {round(best_accs[2][1] * 100, 2)}%"
)
# Out:
# Epoch 1: loss 1.17475, train micro 33.33%, train macro 16.67%, valid micro 33.33%, valid macro 16.67%, test micro 32.89%, test macro 16.5%
# Epoch 2: loss 1.03654, train micro 33.17%, train macro 25.91%, valid micro 25.33%, valid macro 14.92%, test micro 28.19%, test macro 18.5%
# Epoch 3: loss 0.8279, train micro 36.5%, train macro 25.55%, valid micro 35.33%, valid macro 23.99%, test micro 32.09%, test macro 21.7%
# Epoch 4: loss 0.77229, train micro 36.83%, train macro 28.02%, valid micro 28.67%, valid macro 18.6%, test micro 33.84%, test macro 23.79%
# Epoch 5: loss 0.71101, train micro 62.17%, train macro 54.27%, valid micro 57.33%, valid macro 50.04%, test micro 58.49%, test macro 52.08%
# Epoch 6: loss 0.68377, train micro 65.83%, train macro 64.45%, valid micro 67.33%, valid macro 67.8%, test micro 58.31%, test macro 57.66%
# Epoch 7: loss 0.66549, train micro 62.17%, train macro 52.14%, valid micro 60.33%, valid macro 50.69%, test micro 59.91%, test macro 50.22%
# Epoch 8: loss 0.64814, train micro 62.33%, train macro 52.27%, valid micro 62.67%, valid macro 52.52%, test micro 60.14%, test macro 50.43%
# Epoch 9: loss 0.63332, train micro 62.33%, train macro 52.27%, valid micro 62.67%, valid macro 52.52%, test micro 60.14%, test macro 50.43%
# Epoch 10: loss 0.62164, train micro 62.33%, train macro 52.27%, valid micro 62.67%, valid macro 52.52%, test micro 60.14%, test macro 50.43%
# Epoch 11: loss 0.61006, train micro 62.33%, train macro 52.27%, valid micro 62.67%, valid macro 52.52%, test micro 60.14%, test macro 50.43%
# Epoch 12: loss 0.59795, train micro 62.33%, train macro 52.27%, valid micro 62.67%, valid macro 52.52%, test micro 60.14%, test macro 50.43%
# Epoch 13: loss 0.58706, train micro 62.33%, train macro 52.27%, valid micro 62.67%, valid macro 52.52%, test micro 60.14%, test macro 50.43%
# Epoch 14: loss 0.58073, train micro 62.33%, train macro 52.27%, valid micro 62.67%, valid macro 52.52%, test micro 60.14%, test macro 50.43%
# Epoch 15: loss 0.57291, train micro 62.33%, train macro 52.27%, valid micro 63.0%, valid macro 52.77%, test micro 60.19%, test macro 50.47%
# Epoch 16: loss 0.56536, train micro 66.67%, train macro 64.92%, valid micro 73.33%, valid macro 72.85%, test micro 60.71%, test macro 58.79%
# Epoch 17: loss 0.5588, train micro 70.67%, train macro 70.61%, valid micro 75.0%, valid macro 74.76%, test micro 60.8%, test macro 60.28%
# Epoch 18: loss 0.55078, train micro 72.33%, train macro 71.81%, valid micro 73.67%, valid macro 72.51%, test micro 60.42%, test macro 58.2%
# Epoch 19: loss 0.54223, train micro 69.67%, train macro 67.6%, valid micro 63.67%, valid macro 55.67%, test micro 60.66%, test macro 55.51%
# Epoch 20: loss 0.53259, train micro 70.67%, train macro 69.07%, valid micro 64.33%, valid macro 57.85%, test micro 61.27%, test macro 57.25%
# Epoch 21: loss 0.51817, train micro 71.83%, train macro 71.95%, valid micro 68.67%, valid macro 67.68%, test micro 63.76%, test macro 63.46%
# Epoch 22: loss 0.50384, train micro 72.17%, train macro 71.36%, valid micro 68.67%, valid macro 65.41%, test micro 64.0%, test macro 61.99%
# Epoch 23: loss 0.48515, train micro 73.83%, train macro 74.29%, valid micro 75.0%, valid macro 75.34%, test micro 60.94%, test macro 61.94%
# Epoch 24: loss 0.46955, train micro 61.0%, train macro 60.85%, valid micro 70.0%, valid macro 70.8%, test micro 50.02%, test macro 50.85%
# Epoch 25: loss 0.46104, train micro 42.17%, train macro 34.54%, valid micro 38.33%, valid macro 29.39%, test micro 37.04%, test macro 26.68%
# Epoch 26: loss 0.4619, train micro 44.17%, train macro 36.98%, valid micro 41.67%, valid macro 34.22%, test micro 39.53%, test macro 29.64%
# Epoch 27: loss 0.42835, train micro 47.83%, train macro 44.35%, valid micro 48.33%, valid macro 45.63%, test micro 44.0%, test macro 38.89%
# Epoch 28: loss 0.465, train micro 60.83%, train macro 59.8%, valid micro 59.33%, valid macro 55.56%, test micro 56.05%, test macro 52.05%
# Epoch 29: loss 0.40458, train micro 41.5%, train macro 33.32%, valid micro 41.67%, valid macro 33.07%, test micro 39.15%, test macro 27.53%
# Epoch 30: loss 0.40385, train micro 39.67%, train macro 30.31%, valid micro 37.67%, valid macro 26.27%, test micro 38.02%, test macro 25.14%
# Epoch 31: loss 0.39764, train micro 40.5%, train macro 31.7%, valid micro 39.33%, valid macro 29.11%, test micro 38.73%, test macro 26.63%
# Epoch 32: loss 0.37849, train micro 46.5%, train macro 41.36%, valid micro 46.33%, valid macro 39.38%, test micro 42.4%, test macro 33.01%
# Epoch 33: loss 0.35896, train micro 48.5%, train macro 44.18%, valid micro 48.0%, valid macro 41.81%, test micro 44.14%, test macro 35.86%
# Epoch 34: loss 0.33955, train micro 44.17%, train macro 36.87%, valid micro 43.0%, valid macro 35.13%, test micro 41.13%, test macro 30.19%
# Epoch 35: loss 0.31474, train micro 39.33%, train macro 28.34%, valid micro 36.33%, valid macro 23.17%, test micro 36.66%, test macro 21.32%
# Epoch 36: loss 0.29574, train micro 41.0%, train macro 31.13%, valid micro 37.33%, valid macro 24.68%, test micro 37.6%, test macro 23.84%
# Epoch 37: loss 0.27189, train micro 44.17%, train macro 36.66%, valid micro 39.67%, valid macro 29.13%, test micro 40.05%, test macro 28.22%
# Epoch 38: loss 0.24277, train micro 49.33%, train macro 44.85%, valid micro 44.67%, valid macro 38.13%, test micro 42.92%, test macro 33.24%
# Epoch 39: loss 0.21483, train micro 53.17%, train macro 50.0%, valid micro 45.33%, valid macro 38.57%, test micro 43.76%, test macro 34.2%
# Epoch 40: loss 0.18631, train micro 54.5%, train macro 51.59%, valid micro 46.0%, valid macro 39.48%, test micro 44.85%, test macro 35.66%
# Epoch 41: loss 0.1608, train micro 57.17%, train macro 54.87%, valid micro 47.0%, valid macro 41.04%, test micro 45.98%, test macro 37.48%
# Epoch 42: loss 0.13672, train micro 60.33%, train macro 58.73%, valid micro 48.0%, valid macro 42.65%, test micro 47.15%, test macro 39.69%
# Epoch 43: loss 0.1177, train micro 61.17%, train macro 59.82%, valid micro 50.0%, valid macro 45.09%, test micro 46.07%, test macro 37.73%
# Epoch 44: loss 0.10189, train micro 59.5%, train macro 57.38%, valid micro 48.0%, valid macro 41.87%, test micro 44.09%, test macro 34.18%
# Epoch 45: loss 0.08579, train micro 66.67%, train macro 65.22%, valid micro 52.0%, valid macro 47.69%, test micro 47.01%, test macro 38.85%
# Epoch 46: loss 0.07418, train micro 78.83%, train macro 78.02%, valid micro 61.33%, valid macro 59.0%, test micro 53.69%, test macro 49.08%
# Epoch 47: loss 0.07188, train micro 82.5%, train macro 82.34%, valid micro 67.67%, valid macro 67.01%, test micro 58.68%, test macro 55.52%
# Epoch 48: loss 0.06841, train micro 90.17%, train macro 90.21%, valid micro 79.0%, valid macro 79.34%, test micro 65.88%, test macro 64.27%
# Epoch 49: loss 0.05051, train micro 93.5%, train macro 93.45%, valid micro 87.0%, valid macro 87.17%, test micro 72.19%, test macro 71.73%
# Epoch 50: loss 0.09159, train micro 91.5%, train macro 91.52%, valid micro 83.0%, valid macro 83.3%, test micro 68.33%, test macro 67.03%
# Epoch 51: loss 0.0546, train micro 92.33%, train macro 92.39%, valid micro 84.0%, valid macro 84.23%, test micro 69.65%, test macro 68.52%
# Epoch 52: loss 0.04898, train micro 93.83%, train macro 93.84%, valid micro 85.0%, valid macro 85.24%, test micro 72.19%, test macro 71.41%
# Epoch 53: loss 0.04757, train micro 93.33%, train macro 93.41%, valid micro 83.0%, valid macro 83.43%, test micro 70.45%, test macro 69.26%
# Epoch 54: loss 0.03204, train micro 93.33%, train macro 93.41%, valid micro 83.33%, valid macro 83.77%, test micro 69.51%, test macro 68.15%
# Epoch 55: loss 0.03019, train micro 94.0%, train macro 94.07%, valid micro 84.0%, valid macro 84.45%, test micro 69.65%, test macro 68.18%
# Epoch 56: loss 0.02694, train micro 95.0%, train macro 95.05%, valid micro 85.67%, valid macro 86.04%, test micro 70.59%, test macro 69.3%
# Epoch 57: loss 0.02217, train micro 96.0%, train macro 96.0%, valid micro 88.0%, valid macro 88.09%, test micro 71.53%, test macro 70.62%
# Epoch 58: loss 0.02024, train micro 95.0%, train macro 94.99%, valid micro 84.0%, valid macro 84.04%, test micro 70.64%, test macro 69.62%
# Epoch 59: loss 0.01749, train micro 96.0%, train macro 95.99%, valid micro 85.0%, valid macro 85.06%, test micro 71.62%, test macro 70.77%
# Epoch 60: loss 0.01537, train micro 98.33%, train macro 98.33%, valid micro 90.0%, valid macro 89.94%, test micro 75.2%, test macro 74.67%
# Epoch 61: loss 0.01479, train micro 99.0%, train macro 99.0%, valid micro 88.0%, valid macro 88.25%, test micro 74.87%, test macro 74.05%
# Epoch 62: loss 0.01192, train micro 98.83%, train macro 98.84%, valid micro 90.67%, valid macro 90.87%, test micro 75.86%, test macro 74.97%
# Epoch 63: loss 0.01162, train micro 99.67%, train macro 99.67%, valid micro 95.33%, valid macro 95.36%, test micro 79.95%, test macro 79.49%
# Epoch 64: loss 0.01115, train micro 99.83%, train macro 99.83%, valid micro 95.33%, valid macro 95.35%, test micro 80.33%, test macro 79.98%
# Epoch 65: loss 0.00879, train micro 100.0%, train macro 100.0%, valid micro 94.33%, valid macro 94.39%, test micro 79.58%, test macro 79.28%
# Epoch 66: loss 0.00751, train micro 100.0%, train macro 100.0%, valid micro 92.67%, valid macro 92.74%, test micro 79.34%, test macro 79.11%
# Epoch 67: loss 0.00673, train micro 100.0%, train macro 100.0%, valid micro 90.0%, valid macro 90.0%, test micro 78.35%, test macro 78.08%
# Epoch 68: loss 0.00593, train micro 100.0%, train macro 100.0%, valid micro 89.0%, valid macro 88.94%, test micro 78.49%, test macro 78.21%
# Epoch 69: loss 0.00562, train micro 99.67%, train macro 99.67%, valid micro 88.33%, valid macro 88.27%, test micro 78.07%, test macro 77.77%
# Epoch 70: loss 0.00508, train micro 99.67%, train macro 99.67%, valid micro 88.67%, valid macro 88.67%, test micro 78.73%, test macro 78.44%
# Epoch 71: loss 0.00464, train micro 99.83%, train macro 99.83%, valid micro 90.0%, valid macro 90.03%, test micro 78.87%, test macro 78.59%
# Epoch 72: loss 0.00422, train micro 100.0%, train macro 100.0%, valid micro 91.33%, valid macro 91.36%, test micro 79.39%, test macro 79.13%
# Epoch 73: loss 0.00384, train micro 100.0%, train macro 100.0%, valid micro 92.33%, valid macro 92.38%, test micro 80.09%, test macro 79.87%
# Epoch 74: loss 0.00355, train micro 100.0%, train macro 100.0%, valid micro 93.33%, valid macro 93.36%, test micro 80.89%, test macro 80.69%
# Epoch 75: loss 0.00329, train micro 100.0%, train macro 100.0%, valid micro 93.33%, valid macro 93.36%, test micro 81.04%, test macro 80.81%
# Epoch 76: loss 0.00301, train micro 100.0%, train macro 100.0%, valid micro 93.0%, valid macro 93.03%, test micro 80.94%, test macro 80.74%
# Epoch 77: loss 0.00276, train micro 100.0%, train macro 100.0%, valid micro 92.0%, valid macro 92.03%, test micro 81.22%, test macro 81.05%
# Epoch 78: loss 0.00257, train micro 100.0%, train macro 100.0%, valid micro 91.67%, valid macro 91.69%, test micro 81.04%, test macro 80.88%
# Epoch 79: loss 0.00242, train micro 100.0%, train macro 100.0%, valid micro 91.67%, valid macro 91.68%, test micro 81.41%, test macro 81.26%
# Epoch 80: loss 0.00228, train micro 100.0%, train macro 100.0%, valid micro 93.0%, valid macro 93.02%, test micro 81.6%, test macro 81.47%
# Epoch 81: loss 0.00214, train micro 100.0%, train macro 100.0%, valid micro 93.67%, valid macro 93.67%, test micro 82.54%, test macro 82.42%
# Epoch 82: loss 0.00203, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.67%, test micro 82.92%, test macro 82.79%
# Epoch 83: loss 0.00194, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.67%, test micro 82.87%, test macro 82.75%
# Epoch 84: loss 0.00185, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.67%, test micro 82.78%, test macro 82.64%
# Epoch 85: loss 0.00176, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.67%, test micro 82.49%, test macro 82.37%
# Epoch 86: loss 0.00168, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.67%, test micro 82.35%, test macro 82.22%
# Epoch 87: loss 0.00162, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.67%, test micro 82.35%, test macro 82.23%
# Epoch 88: loss 0.00156, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.67%, test micro 82.68%, test macro 82.57%
# Epoch 89: loss 0.00149, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.54%, test macro 82.45%
# Epoch 90: loss 0.00143, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.45%, test macro 82.37%
# Epoch 91: loss 0.00138, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.68%, test macro 82.61%
# Epoch 92: loss 0.00134, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.59%, test macro 82.52%
# Epoch 93: loss 0.00129, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.35%, test macro 82.28%
# Epoch 94: loss 0.00125, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.26%, test macro 82.19%
# Epoch 95: loss 0.00121, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.31%, test macro 82.23%
# Epoch 96: loss 0.00117, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.35%, test macro 82.27%
# Epoch 97: loss 0.00114, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.35%, test macro 82.27%
# Epoch 98: loss 0.00111, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.35%, test macro 82.27%
# Epoch 99: loss 0.00108, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.31%, test macro 82.23%
# Epoch 100: loss 0.00105, train micro 100.0%, train macro 100.0%, valid micro 94.67%, valid macro 94.66%, test micro 82.35%, test macro 82.28%
# Best model: train micro 99.67%, train macro 99.67%, valid micro 95.33%, valid macro 95.36%, test micro 79.95%, test macro 79.49%

# %% [markdown]
# ## Question 2.3: What is the maximum **micro** F1 score you could get for the best_model on test set when using the attention aggregation? (4 points)
#
# Submit your answers on Gradescope.

# %% [markdown]
# ## Question 2.4: What is the maximum **macro** F1 score you could get for the best_model on test set when using the attention aggregation? (4 points)
#
# Submit your answers on Gradescope.

# %% [markdown]
# ## Attention for each Message Type
#
# Through message type level attention we can learn that which message type is more important to which layer.
#
# Here we will print out and show that each layer pay how much attention on each message type.

# %%
if model.convs1.alpha is not None and model.convs2.alpha is not None:
    for idx, message_type in model.convs1.mapping.items():
        print(f"Layer 1 has attention {model.convs1.alpha[idx]} on message type {message_type}")
    for idx, message_type in model.convs2.mapping.items():
        print(f"Layer 2 has attention {model.convs2.alpha[idx]} on message type {message_type}")
# Out:
# Layer 1 has attention 0.9984670281410217 on message type ('paper', 'author', 'paper')
# Layer 1 has attention 0.0015329038724303246 on message type ('paper', 'subject', 'paper')
# Layer 2 has attention 0.9625114798545837 on message type ('paper', 'author', 'paper')
# Layer 2 has attention 0.03748856484889984 on message type ('paper', 'subject', 'paper')

# %% [markdown]
# # Submission
#
# In order to get credit, you must go submit your answers on Gradescope.
#
# Also, you need to submit the `ipynb` file of Colab 4, by clicking `File` and `Download .ipynb`. Please make sure that your output of each cell is available in your `ipynb` file.
